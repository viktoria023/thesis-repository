# %%
# import os

# repo_url = "https://github.com/fowler-lab/tuberculosis-rnap-subpopulations.git"
# repo_dir = "tuberculosis-rnap-subpopulations"

# if not os.path.exists(repo_dir):
#     !git clone {repo_url}

# %cd {repo_dir}

# %%
import numpy as np
import pandas as pd
import copy
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import json
import seaborn as sns
import re

from scipy.stats import fisher_exact
from tqdm import tqdm
from src.utils import calculate_results_row, plot_performance_frs, plot_histogram, plot_frs_histogram, plot_compensation_barplot

# make the default font size point 7
plt.rcParams.update({"font.size": 7})

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load datasets
#
# First let's load the predicted effects for mutations in *rpoB* (which is the only gene in the WHOv2 catalogue that confers resistance to RIF). This will let us identify all the definite resistance-associated variants. (If we used the WHOv2 catalogue we'd have to unpack and deal with generic rules which is harder).

# %%
effects = pd.read_parquet('data/cryptic_3/RIF_EFFECTS.parquet', engine='pyarrow')

resistance_mutations = effects.GENE_MUTATION.unique()
resistance_mutations = resistance_mutations.astype(str)

# Apply a mask to filter out unclear mutations (those with 'X' in them)
mask = np.char.find(resistance_mutations, 'X') == -1
resistance_mutations = resistance_mutations[mask]

print(f"There are {len(resistance_mutations)} unique resistance mutations according to WHOv2 in our dataset")

print(f"These include {resistance_mutations[:3]}")
# Out:
# There are 131 unique resistance mutations according to WHOv2 in our dataset
# These include ['rpoB_S450L' 'rpoB_H445D' 'rpoB_D435V']

# %% [markdown]
# We will get our list of compensatory mutations from this paper
#
# > Brunner V, Fowler PW
# >
# > Compensatory mutations are associated with increased in vitro growth in resistant clinical samples of *Mycobacterium tuberculosis*.
# >
# > mGen 10:001187 doi:10.1099/mgen.0.001187
#
# The list is publicly available from here:
#
# https://github.com/fowler-lab/tb-rnap-compensation

# %%
CMs = pd.read_csv('data/final_CM_hit_list.csv')
CMs = CMs[CMs.homoplasy == True]
compensatory_mutations = CMs['putative CM'].unique()

print(f"There are {len(compensatory_mutations)} compensatory mutations in the RNAP identified by this study")
print(f"These include {compensatory_mutations[:3]}")
# Out:
# There are 51 compensatory mutations in the RNAP identified by this study
# These include ['rpoC_V483G' 'rpoC_I491V' 'rpoC_V483A']

# %%
# #uncomment this to remove the mutation rpoC_F452L from the compensatory mutations list
# compensatory_mutations = np.delete(compensatory_mutations, np.where(compensatory_mutations == 'rpoC_F452L'))

# compensatory_mutations

# %% [markdown]
# ### Genetics
#
# First let's load the dataframe of all samples that we have whole genome sequencing data

# %%
genomes = pd.read_parquet('data/cryptic_3/GENOMES.parquet', engine='pyarrow')
genomes.reset_index(inplace=True)
genomes.set_index('UNIQUEID', inplace = True)
genomes['HAS_GENOME'] = True
print(f"There are {len(genomes)} unique genomes in the dataset")
# Out:
# There are 41575 unique genomes in the dataset

# %% [markdown]
# Now load all the mutations in the RNA polymerase and identify which mutations are associated with resistance and which have been identified as compensatory

# %%
mutations = pd.read_parquet('data/cryptic_3/RNAP_MUTATIONS.parquet', engine='pyarrow')

mutations['GENE_MUTATION'] = np.where(
    mutations['IS_MINOR'],  # Condition: if IS_MINOR_ALLELE is True
    mutations['GENE'].astype(str) + '_' + mutations['MINOR_MUTATION'].astype(str),  # Then: use GENE + MINOR_MUTATION
    mutations['GENE'].astype(str) + '_' + mutations['MUTATION'].astype(str)  # Else: use GENE + MUTATION
)

mutations
# Out:
#                                                UNIQUEID  GENE MUTATION  REF
# 1637                 site.02.subj.0069.lab.22A019.iso.1  rpoB    S450L  tcg  \
# 1638                 site.02.subj.0069.lab.22A019.iso.1  rpoB   A1075A  gct
# 1639                 site.02.subj.0069.lab.22A019.iso.1  rpoC    V483A  gtg
# 4017             site.ENA.subj.SAMEA2533644.lab.1.iso.1  rpoB   A1075A  gct
# 4018             site.ENA.subj.SAMEA2533644.lab.1.iso.1  rpoC    A172V  gcc
# ...                                                 ...   ...      ...  ...
# 61559110   site.10.subj.YA00084833.lab.YA00084833.iso.1  rpoB    G876G  ggt
# 61559111   site.10.subj.YA00084833.lab.YA00084833.iso.1  rpoB   A1075A  gct
# 61559112   site.10.subj.YA00084833.lab.YA00084833.iso.1  rpoC    A861S  gcg
# 61560265  site.07.subj.FD_127_4242.lab.12_0613161.iso.1  rpoB    T361T  acc
# 61560266  site.07.subj.FD_127_4242.lab.12_0613161.iso.1  rpoC    G594E  ggg
#
#           ALT  NUCLEOTIDE_NUMBER  NUCLEOTIDE_INDEX  GENE_POSITION
# 1637      ttg                NaN               NaN          450.0  \
# 1638      gcc                NaN               NaN         1075.0
# 1639      gcg                NaN               NaN          483.0
# 4017      gcc                NaN               NaN         1075.0
# 4018      gtc                NaN               NaN          172.0
# ...       ...                ...               ...            ...
# 61559110  ggg                NaN               NaN          876.0
# 61559111  gcc                NaN               NaN         1075.0
# 61559112  tcg                NaN               NaN          861.0
# 61560265  act                NaN               NaN          361.0
# 61560266  gag                NaN               NaN          594.0
#
#           CODES_PROTEIN  INDEL_LENGTH  ... AMINO_ACID_NUMBER
# 1637               True           NaN  ...             450.0  \
# 1638               True           NaN  ...            1075.0
# 1639               True           NaN  ...             483.0
# 4017               True           NaN  ...            1075.0
# 4018               True           NaN  ...             172.0
# ...                 ...           ...  ...               ...
# 61559110           True           NaN  ...             876.0
# 61559111           True           NaN  ...            1075.0
# 61559112           True           NaN  ...             861.0
# 61560265           True           NaN  ...             361.0
# 61560266           True           NaN  ...             594.0
#
#           AMINO_ACID_SEQUENCE NUMBER_NUCLEOTIDE_CHANGES  IS_NULL  IS_MINOR
# 1637                        L                       1.0    False     False  \
# 1638                        A                       1.0    False     False
# 1639                        A                       1.0    False     False
# 4017                        A                       1.0    False     False
# 4018                        V                       1.0    False     False
# ...                       ...                       ...      ...       ...
# 61559110                    G                       1.0    False     False
# 61559111                    A                       1.0    False     False
# 61559112                    S                       1.0    False     False
# 61560265                    T                       1.0    False     False
# 61560266                    E                       1.0    False     False
#
#           MINOR_MUTATION MINOR_READS  COVERAGE  FRS  GENE_MUTATION
# 1637                None         NaN      64.0  1.0     rpoB_S450L
# 1638                None         NaN     114.0  1.0    rpoB_A1075A
# 1639                None         NaN     108.0  1.0     rpoC_V483A
# 4017                None         NaN     104.0  1.0    rpoB_A1075A
# 4018                None         NaN     102.0  1.0     rpoC_A172V
# ...                  ...         ...       ...  ...            ...
# 61559110            None         NaN     120.0  1.0     rpoB_G876G
# 61559111            None         NaN     109.0  1.0    rpoB_A1075A
# 61559112            None         NaN     126.0  1.0     rpoC_A861S
# 61560265            None         NaN      75.0  1.0     rpoB_T361T
# 61560266            None         NaN     125.0  1.0     rpoC_G594E
#
# [101020 rows x 21 columns]

# %%
mutations['IS_RESISTANT_MUTATION'] = mutations['GENE_MUTATION'].isin(resistance_mutations)
mutations['IS_COMPENSATORY_MUTATION'] = mutations['GENE_MUTATION'].isin(compensatory_mutations)
mutations.set_index('UNIQUEID', inplace=True)

print(f"There are {len(mutations)} RNAP mutations in {len(mutations.index.unique())} samples that have been whole genome sequenced in our dataset")

rpoB = mutations[mutations.GENE == 'rpoB']

print(f"{rpoB[~rpoB.IS_MINOR].index.nunique()} samples contain one or more of {len(rpoB[~rpoB.IS_MINOR])} mutations in rpoB supported by an FRS ≥ 0.90")
print(f"{rpoB[rpoB.IS_MINOR].index.nunique()} samples contain one or more of {len(rpoB[rpoB.IS_MINOR])} mutations in rpoB supported by an FRS < 0.90")
mutations[:3]
# Out:
# There are 101020 RNAP mutations in 37594 samples that have been whole genome sequenced in our dataset
# 31347 samples contain one or more of 58789 mutations in rpoB supported by an FRS ≥ 0.90
# 1372 samples contain one or more of 1940 mutations in rpoB supported by an FRS < 0.90
# 31347 samples contain one or more of 58789 mutations in rpoB supported by an FRS ≥ 0.90
# 1372 samples contain one or more of 1940 mutations in rpoB supported by an FRS < 0.90
#                                     GENE MUTATION  REF  ALT
# UNIQUEID
# site.02.subj.0069.lab.22A019.iso.1  rpoB    S450L  tcg  ttg  \
# site.02.subj.0069.lab.22A019.iso.1  rpoB   A1075A  gct  gcc
# site.02.subj.0069.lab.22A019.iso.1  rpoC    V483A  gtg  gcg
#
#                                     NUCLEOTIDE_NUMBER  NUCLEOTIDE_INDEX
# UNIQUEID
# site.02.subj.0069.lab.22A019.iso.1                NaN               NaN  \
# site.02.subj.0069.lab.22A019.iso.1                NaN               NaN
# site.02.subj.0069.lab.22A019.iso.1                NaN               NaN
#
#                                     GENE_POSITION  CODES_PROTEIN
# UNIQUEID
# site.02.subj.0069.lab.22A019.iso.1          450.0           True  \
# site.02.subj.0069.lab.22A019.iso.1         1075.0           True
# site.02.subj.0069.lab.22A019.iso.1          483.0           True
#
#                                     INDEL_LENGTH INDEL_NUCLEOTIDES  ...
# UNIQUEID                                                            ...
# site.02.subj.0069.lab.22A019.iso.1           NaN              None  ...  \
# site.02.subj.0069.lab.22A019.iso.1           NaN              None  ...
# site.02.subj.0069.lab.22A019.iso.1           NaN              None  ...
#
#                                     NUMBER_NUCLEOTIDE_CHANGES IS_NULL
# UNIQUEID
# site.02.subj.0069.lab.22A019.iso.1                        1.0   False  \
# site.02.subj.0069.lab.22A019.iso.1                        1.0   False
# site.02.subj.0069.lab.22A019.iso.1                        1.0   False
#
#                                     IS_MINOR  MINOR_MUTATION  MINOR_READS
# UNIQUEID
# site.02.subj.0069.lab.22A019.iso.1     False            None          NaN  \
# site.02.subj.0069.lab.22A019.iso.1     False            None          NaN
# site.02.subj.0069.lab.22A019.iso.1     False            None          NaN
#
#                                    COVERAGE  FRS  GENE_MUTATION
# UNIQUEID
# site.02.subj.0069.lab.22A019.iso.1     64.0  1.0     rpoB_S450L  \
# site.02.subj.0069.lab.22A019.iso.1    114.0  1.0    rpoB_A1075A
# site.02.subj.0069.lab.22A019.iso.1    108.0  1.0     rpoC_V483A
#
#                                     IS_RESISTANT_MUTATION
# UNIQUEID
# site.02.subj.0069.lab.22A019.iso.1                   True  \
# site.02.subj.0069.lab.22A019.iso.1                  False
# site.02.subj.0069.lab.22A019.iso.1                  False
#
#                                    IS_COMPENSATORY_MUTATION
# UNIQUEID
# site.02.subj.0069.lab.22A019.iso.1                    False
# site.02.subj.0069.lab.22A019.iso.1                    False
# site.02.subj.0069.lab.22A019.iso.1                     True
#
# [3 rows x 22 columns]

# %% [markdown]
# ### Drug susceptibility measurements
#
# Let's load in the DTS data; one problem we will have to solve is that some samples have more than one rifampicin measurement. For example, they could have an MIC from a UKMYC6 96-well broth microdilution plate but they could also have an R/S from a MGIT960 tube. The approach we will take is to classify any samples as resistant if any of their DST results indicate resistance and we will keep, by preference, the UKMYC measurements since we have more detailed information on these.

# %%
phenotypes = pd.read_pickle('data/cryptic_3/DST_MEASUREMENTS.pkl.gz')
phenotypes.reset_index(inplace=True)
phenotypes = phenotypes[phenotypes.DRUG == 'RIF']
phenotypes['HAS_DST'] = True

agg_phenotypes = phenotypes[['UNIQUEID', 'DRUG']].groupby(['UNIQUEID']).count()
agg_phenotypes.value_counts(dropna=False)

multiples = agg_phenotypes[agg_phenotypes.DRUG>1].index
singles = agg_phenotypes[agg_phenotypes.DRUG==1].index

print(f"There are {len(singles) + len(multiples)} samples with at least one RIF DST measurement.")
print(f"Of these {len(singles)} samples have a single DST measurement and {len(multiples)} have multiple DST measurements.")

phenotypes.set_index('UNIQUEID', inplace = True)
phenotypes[:3]
# Out:
# There are 52148 samples with at least one RIF DST measurement.
# Of these 43150 samples have a single DST measurement and 8998 have multiple DST measurements.
#                                      DRUG        SOURCE      METHOD_1
# UNIQUEID
# site.24.subj.PT-2.lab.1997-606.iso.1  RIF  SEQTREAT2020  liquid media  \
# site.24.subj.PT-4.lab.1998-151.iso.1  RIF  SEQTREAT2020  liquid media
# site.24.subj.PT-5.lab.1998-713.iso.1  RIF  SEQTREAT2020  liquid media
#
#                                      METHOD_2   METHOD_3 METHOD_CC METHOD_MIC
# UNIQUEID
# site.24.subj.PT-2.lab.1997-606.iso.1     MGIT  BACTEC460       1.0        NaN  \
# site.24.subj.PT-4.lab.1998-151.iso.1     MGIT  BACTEC460       1.0        NaN
# site.24.subj.PT-5.lab.1998-713.iso.1     MGIT  BACTEC460       1.0        NaN
#
#                                      PHENOTYPE QUALITY  HAS_DST
# UNIQUEID
# site.24.subj.PT-2.lab.1997-606.iso.1         S  MEDIUM     True
# site.24.subj.PT-4.lab.1998-151.iso.1         S  MEDIUM     True
# site.24.subj.PT-5.lab.1998-713.iso.1         S  MEDIUM     True

# %%
phenotypes.METHOD_2.value_counts()
# Out:
# METHOD_2
# microdilution plate    24172
# MGIT                   23682
# LJ                      7266
#                         3030
# middlebrook             1563
# Name: count, dtype: int64

# %%
# go through the list of UNIQUEIDs with multiple RIF DST measurements and apply the logic described above

table = []
for uid in tqdm(multiples):

    phenotype=None
    first_row=True
    for idx,row in phenotypes.loc[uid].iterrows():

        # if this is the first entry, just add it
        if first_row:

            table.append(row)
            phenotype=row.PHENOTYPE
            method=row.METHOD_3
            first_row=False

        else:   

            # but if the new phenotype is resistant, add the row
            if phenotype=='S' and row.PHENOTYPE == 'R':
                table[-1] = row

            # or replace with the UKMYC result if the phenotypes are the same 
            elif phenotype==row.PHENOTYPE and row.METHOD_3 in ['UKMYC5', 'UKMYC6']:
                table[-1] = row

phenotypes = pd.concat([phenotypes.loc[singles], pd.DataFrame(table)])
assert phenotypes.index.duplicated().sum()==0, 'there are still duplicates in the table'
phenotypes.index.name = 'UNIQUEID'
phenotypes = phenotypes[phenotypes.PHENOTYPE.isin(['S', 'R'])]
print(f"We have {len(phenotypes)} samples with a definite (R/S) DST measurement for RIF")

phenotypes = phenotypes[phenotypes.QUALITY!='LOW']
print(f"Removing samples where there is disagreement about the phenotype leaves {len(phenotypes)} samples")

phenotypes[:3]
# Out:
# 100%|██████████| 8998/8998 [00:04<00:00, 2047.07it/s]
# 100%|██████████| 8998/8998 [00:04<00:00, 2047.07it/s]
# We have 51183 samples with a definite (R/S) DST measurement for RIF
# Removing samples where there is disagreement about the phenotype leaves 48031 samples
#                                           DRUG    SOURCE     METHOD_1
# UNIQUEID
# site.00.subj.1000347.lab.H111540004.iso.1  RIF  NEJM2018  solid media  \
# site.00.subj.1000595.lab.H123460044.iso.1  RIF  NEJM2018  solid media
# site.00.subj.1004213.lab.H111060034.iso.1  RIF  NEJM2018  solid media
#
#                                           METHOD_2          METHOD_3
# UNIQUEID
# site.00.subj.1000347.lab.H111540004.iso.1       LJ  resistance ratio  \
# site.00.subj.1000595.lab.H123460044.iso.1       LJ  resistance ratio
# site.00.subj.1004213.lab.H111060034.iso.1       LJ  resistance ratio
#
#                                           METHOD_CC METHOD_MIC PHENOTYPE
# UNIQUEID
# site.00.subj.1000347.lab.H111540004.iso.1                  NaN         R  \
# site.00.subj.1000595.lab.H123460044.iso.1                  NaN         R
# site.00.subj.1004213.lab.H111060034.iso.1                  NaN         R
#
#                                           QUALITY  HAS_DST
# UNIQUEID
# site.00.subj.1000347.lab.H111540004.iso.1  MEDIUM     True
# site.00.subj.1000595.lab.H123460044.iso.1  MEDIUM     True
# site.00.subj.1004213.lab.H111060034.iso.1  MEDIUM     True

# %% [markdown]
# ### Merging
#
# Now we can join the two sets of samples to identify those which have both WGS and DST data, which should be all of them.

# %%
samples = genomes[['HAS_GENOME']].join(phenotypes[['HAS_DST','PHENOTYPE']], how='left')
samples.HAS_DST = samples.HAS_DST.fillna(False)
print(f"We have {(samples.HAS_DST).sum()} samples with both WGS data and a definite DST measurement for RIF")
samples[:3]
# Out:
# We have 35538 samples with both WGS data and a definite DST measurement for RIF
#                                               HAS_GENOME  HAS_DST PHENOTYPE
# UNIQUEID
# site.10.subj.YA00019967.lab.YA00019967.iso.1        True     True         R
# site.ENA.subj.SAMEA1019012.lab.1.iso.1              True     True         S
# site.04.subj.06941.lab.932089.iso.1                 True     True         R

# %%
# aggregate mutations by UNIQUEID and keep columns of interest: define FRS to be the maximum of any resistant mutations, otherwise the maximum of the remaining mutations

def aggregate_minor_major_allele(group):

    resistant_frs_value = None
    compensatory_frs_value = None

    # Check if any row has both IS_MINOR_ALLELE and RESISTANT_MUTATION    
    resistant_minor_allele_flag = any((group['IS_MINOR']) & (group['IS_RESISTANT_MUTATION']))

    # Check if any row both isn't IS_MINOR_ALLELE and RESISTANT_MUTATION
    resistant_major_allele_flag = any((~group['IS_MINOR']) & (group['IS_RESISTANT_MUTATION']))

    # Get the rows where there is a resistant major allele
    resistant_major_allele_rows = group[(~group['IS_MINOR']) & (group['IS_RESISTANT_MUTATION'])]

    # Get the rows where there is a resistant minor allele
    resistant_minor_allele_rows = group[(group['IS_MINOR']) & (group['IS_RESISTANT_MUTATION'])]
    
    if resistant_major_allele_rows.empty:

        if not resistant_minor_allele_rows.empty:

            # If there are resistant minor alleles, get the maximum FRS value for those rows
            resistant_frs_value = resistant_minor_allele_rows['FRS'].max()

    else:

        resistant_frs_value = resistant_major_allele_rows['FRS'].max()

    # Check if any row has both IS_MINOR_ALLELE and COMPENSATORY_MUTATION    
    compensatory_minor_allele_flag = any((group['IS_MINOR']) & (group['IS_COMPENSATORY_MUTATION']))

    # Check if any row both isn't IS_MINOR_ALLELE and COMPENSATORY_MUTATION
    compensatory_major_allele_flag = any((~group['IS_MINOR']) & (group['IS_COMPENSATORY_MUTATION']))

    # Get the rows where there is a resistant major allele
    compensatory_major_allele_rows = group[(~group['IS_MINOR']) & (group['IS_COMPENSATORY_MUTATION'])]

    # Get the rows where there is a resistant minor allele
    compensatory_minor_allele_rows = group[(group['IS_MINOR']) & (group['IS_COMPENSATORY_MUTATION'])]
    
    if compensatory_major_allele_rows.empty:

        if not compensatory_minor_allele_rows.empty:

            # If there are resistant minor alleles, get the maximum FRS value for those rows
            compensatory_frs_value = compensatory_minor_allele_rows['FRS'].max()

    else:

        compensatory_frs_value = compensatory_major_allele_rows['FRS'].max()

    return pd.Series({
        'HAS_RNAP_MUTATIONS': True,
        'HAS_RESISTANT_MUTATION': group['IS_RESISTANT_MUTATION'].max(),
        'N_RAV': group['IS_RESISTANT_MUTATION'].sum(),
        'HAS_MINOR_RAV': resistant_minor_allele_flag,
        'HAS_MAJOR_RAV': resistant_major_allele_flag,
        'MAX_RAV_FRS': resistant_frs_value,  # Use the maximum FRS for any RAVs present
        'HAS_COMPENSATORY_MUTATION': group['IS_COMPENSATORY_MUTATION'].max(),
        'N_CM': group['IS_COMPENSATORY_MUTATION'].sum(),
        'HAS_MINOR_CM': compensatory_minor_allele_flag,
        'HAS_MAJOR_CM': compensatory_major_allele_flag,
        'MAX_CM_FRS': compensatory_frs_value,  # Use the maximum FRS for any compensatory mutations present
    })

# Apply the custom aggregation function
agg_mutations = mutations.groupby('UNIQUEID').apply(aggregate_minor_major_allele).reset_index()
agg_mutations.set_index('UNIQUEID', inplace=True)
agg_mutations[:3]
# Out:
#                                            HAS_RNAP_MUTATIONS
# UNIQUEID
# site.00.subj.1000347.lab.H111540004.iso.1                True  \
# site.00.subj.1000595.lab.H123460044.iso.1                True
# site.00.subj.1004213.lab.H111060034.iso.1                True
#
#                                            HAS_RESISTANT_MUTATION  N_RAV
# UNIQUEID
# site.00.subj.1000347.lab.H111540004.iso.1                    True      1  \
# site.00.subj.1000595.lab.H123460044.iso.1                    True      1
# site.00.subj.1004213.lab.H111060034.iso.1                    True      1
#
#                                            HAS_MINOR_RAV  HAS_MAJOR_RAV
# UNIQUEID
# site.00.subj.1000347.lab.H111540004.iso.1          False           True  \
# site.00.subj.1000595.lab.H123460044.iso.1          False           True
# site.00.subj.1004213.lab.H111060034.iso.1          False           True
#
#                                            MAX_RAV_FRS
# UNIQUEID
# site.00.subj.1000347.lab.H111540004.iso.1          1.0  \
# site.00.subj.1000595.lab.H123460044.iso.1          1.0
# site.00.subj.1004213.lab.H111060034.iso.1          1.0
#
#                                            HAS_COMPENSATORY_MUTATION  N_CM
# UNIQUEID
# site.00.subj.1000347.lab.H111540004.iso.1                      False     0  \
# site.00.subj.1000595.lab.H123460044.iso.1                       True     1
# site.00.subj.1004213.lab.H111060034.iso.1                       True     1
#
#                                            HAS_MINOR_CM  HAS_MAJOR_CM
# UNIQUEID
# site.00.subj.1000347.lab.H111540004.iso.1         False         False  \
# site.00.subj.1000595.lab.H123460044.iso.1         False          True
# site.00.subj.1004213.lab.H111060034.iso.1         False          True
#
#                                            MAX_CM_FRS
# UNIQUEID
# site.00.subj.1000347.lab.H111540004.iso.1         NaN
# site.00.subj.1000595.lab.H123460044.iso.1         1.0
# site.00.subj.1004213.lab.H111060034.iso.1         1.0

# %% [markdown]
# Now we can join the information on the samples which have RNAP mutations to the table of samples with a DST result and a whole genome. We will need to fill in the gaps for those samples which do not have any RNAP mutations.

# %%
samples = samples.join(agg_mutations, how='left')

samples['IS_RESISTANT'] = samples.PHENOTYPE == 'R'

# because we did a left join and hence there were a lot of NaNs to fill in, we need to force these columns to be boolean
for i in ['HAS_RNAP_MUTATIONS', 'HAS_RESISTANT_MUTATION', 'HAS_MINOR_RAV', 'HAS_MAJOR_RAV', 'HAS_COMPENSATORY_MUTATION', 'HAS_MINOR_CM', 'HAS_MAJOR_CM']:
    samples[i] = samples[i].fillna(False)    
    samples[i] = samples[i].astype(bool)

samples[:3]
# Out:
#                                               HAS_GENOME  HAS_DST PHENOTYPE
# UNIQUEID
# site.10.subj.YA00019967.lab.YA00019967.iso.1        True     True         R  \
# site.ENA.subj.SAMEA1019012.lab.1.iso.1              True     True         S
# site.04.subj.06941.lab.932089.iso.1                 True     True         R
#
#                                               HAS_RNAP_MUTATIONS
# UNIQUEID
# site.10.subj.YA00019967.lab.YA00019967.iso.1                True  \
# site.ENA.subj.SAMEA1019012.lab.1.iso.1                      True
# site.04.subj.06941.lab.932089.iso.1                         True
#
#                                               HAS_RESISTANT_MUTATION  N_RAV
# UNIQUEID
# site.10.subj.YA00019967.lab.YA00019967.iso.1                    True    1.0  \
# site.ENA.subj.SAMEA1019012.lab.1.iso.1                         False    0.0
# site.04.subj.06941.lab.932089.iso.1                             True    1.0
#
#                                               HAS_MINOR_RAV  HAS_MAJOR_RAV
# UNIQUEID
# site.10.subj.YA00019967.lab.YA00019967.iso.1          False           True  \
# site.ENA.subj.SAMEA1019012.lab.1.iso.1                False          False
# site.04.subj.06941.lab.932089.iso.1                   False           True
#
#                                               MAX_RAV_FRS
# UNIQUEID
# site.10.subj.YA00019967.lab.YA00019967.iso.1          1.0  \
# site.ENA.subj.SAMEA1019012.lab.1.iso.1                NaN
# site.04.subj.06941.lab.932089.iso.1                   1.0
#
#                                               HAS_COMPENSATORY_MUTATION  N_CM
# UNIQUEID
# site.10.subj.YA00019967.lab.YA00019967.iso.1                       True   1.0  \
# site.ENA.subj.SAMEA1019012.lab.1.iso.1                             True   1.0
# site.04.subj.06941.lab.932089.iso.1                                True   1.0
#
#                                               HAS_MINOR_CM  HAS_MAJOR_CM
# UNIQUEID
# site.10.subj.YA00019967.lab.YA00019967.iso.1         False          True  \
# site.ENA.subj.SAMEA1019012.lab.1.iso.1                True         False
# site.04.subj.06941.lab.932089.iso.1                  False          True
#
#                                               MAX_CM_FRS  IS_RESISTANT
# UNIQUEID
# site.10.subj.YA00019967.lab.YA00019967.iso.1    1.000000          True
# site.ENA.subj.SAMEA1019012.lab.1.iso.1          0.285714         False
# site.04.subj.06941.lab.932089.iso.1             1.000000          True

# %%
print(f"As you might expect nearly all of the samples with no RNAP mutations test as susceptible to RIF:")

samples_with_dst = copy.deepcopy(samples[(samples.HAS_DST) & (samples.HAS_GENOME)])
print(pd.crosstab(samples_with_dst.HAS_RNAP_MUTATIONS, samples_with_dst.IS_RESISTANT))
# Out:
# As you might expect nearly all of the samples with no RNAP mutations test as susceptible to RIF:
# IS_RESISTANT        False  True
# HAS_RNAP_MUTATIONS
# False                3563     49
# True                21565  10361

# %%
homogeneous_samples = samples_with_dst[samples_with_dst.HAS_MAJOR_RAV & ~samples_with_dst.HAS_MINOR_RAV]
heterogeneous_samples = samples_with_dst[~samples_with_dst.HAS_MAJOR_RAV & samples_with_dst.HAS_MINOR_RAV]
mixed_samples = samples_with_dst[samples_with_dst.HAS_MAJOR_RAV & samples_with_dst.HAS_MINOR_RAV]

print(f"There are {samples_with_dst.HAS_RESISTANT_MUTATION.sum()} samples with a RIF resistance-conferring mutation in the RNAP and RIF DST, at any level of read support")
print(f"There are {len(homogeneous_samples)} samples with homogeneous RAVs, {len(heterogeneous_samples)} with heterogeneous RAVs and {len(mixed_samples)} with both")
# Out:
# There are 10568 samples with a RIF resistance-conferring mutation in the RNAP and RIF DST, at any level of read support
# There are 10287 samples with homogeneous RAVs, 261 with heterogeneous RAVs and 20 with both

# %% [markdown]
# Let's have a look at what types of RAV's we see in the different samples types (homogeneous, heterogeneous and mixed)

# %%
#check most common mutations in heterogeneous vs homogeneous and mixed samples
heterogeneous_table = mutations[mutations.index.isin(heterogeneous_samples.index) & (mutations.IS_RESISTANT_MUTATION)].GENE_MUTATION.value_counts()#[:10]
heterogeneous_table = heterogeneous_table.to_frame().reset_index()
heterogeneous_table['percentage'] = round(heterogeneous_table['count'] / sum(heterogeneous_table['count']) * 100, 1)
heterogeneous_table['percentage'] = heterogeneous_table['percentage'].astype(str)

homogeneous_table = mutations[mutations.index.isin(homogeneous_samples.index) & (mutations.IS_RESISTANT_MUTATION)].GENE_MUTATION.value_counts()#[:50]
homogeneous_table = homogeneous_table.to_frame().reset_index()
homogeneous_table['percentage'] = round(homogeneous_table['count'] / sum(homogeneous_table['count']) * 100, 1)
homogeneous_table['percentage'] = homogeneous_table['percentage'].astype(str)

mixed_table = mutations[mutations.index.isin(mixed_samples.index) & (mutations.IS_RESISTANT_MUTATION)].GENE_MUTATION.value_counts()#[:10]
mixed_table = mixed_table.to_frame().reset_index()
mixed_table['percentage'] = round(mixed_table['count'] / sum(mixed_table['count']) * 100, 1)
mixed_table['percentage'] = mixed_table['percentage'].astype(str)

#join all the above tables to the major_table
combined_table = homogeneous_table.merge(heterogeneous_table, on='GENE_MUTATION', how='inner')
combined_table = combined_table.merge(mixed_table, on='GENE_MUTATION', how='outer')
combined_table = combined_table.fillna(0)
combined_table.sort_values('count_x', ascending=False, inplace=True)
combined_table.rename(columns={"GENE_MUTATION": "Mutation", "count_x":"count homogenous", "percentage_x":"% homogenous", "count_y":"count heterogeneous", "percentage_y":"% heterogeneous", "count":"count mixed", "percentage":"% mixed"}, inplace=True)
tmp = combined_table[:20]
print(tmp.to_latex(index = False))
# Out:
# \begin{tabular}{lrlrlrl}
# \toprule
# Mutation & count homogenous & % homogenous & count heterogeneous & % heterogeneous & count mixed & % mixed \\
# \midrule
# rpoB_S450L & 7041.000000 & 66.6 & 144.000000 & 40.6 & 5.000000 & 11.1 \\
# rpoB_D435V & 826.000000 & 7.8 & 27.000000 & 7.6 & 1.000000 & 2.2 \\
# rpoB_H445Y & 374.000000 & 3.5 & 28.000000 & 7.9 & 2.000000 & 4.4 \\
# rpoB_H445D & 368.000000 & 3.5 & 16.000000 & 4.5 & 0.000000 & 0 \\
# rpoB_D435Y & 217.000000 & 2.1 & 17.000000 & 4.8 & 3.000000 & 6.7 \\
# rpoB_L430P & 196.000000 & 1.9 & 19.000000 & 5.4 & 7.000000 & 15.6 \\
# rpoB_L452P & 174.000000 & 1.6 & 20.000000 & 5.6 & 0.000000 & 0 \\
# rpoB_S450W & 142.000000 & 1.3 & 3.000000 & 0.8 & 0.000000 & 0 \\
# rpoB_H445L & 131.000000 & 1.2 & 9.000000 & 2.5 & 0.000000 & 0 \\
# rpoB_I491F & 105.000000 & 1.0 & 3.000000 & 0.8 & 0.000000 & 0 \\
# rpoB_H445R & 92.000000 & 0.9 & 5.000000 & 1.4 & 2.000000 & 4.4 \\
# rpoB_D435G & 85.000000 & 0.8 & 4.000000 & 1.1 & 1.000000 & 2.2 \\
# rpoB_H445N & 76.000000 & 0.7 & 8.000000 & 2.3 & 4.000000 & 8.9 \\
# rpoB_V170F & 73.000000 & 0.7 & 3.000000 & 0.8 & 1.000000 & 2.2 \\
# rpoB_D435F & 43.000000 & 0.4 & 2.000000 & 0.6 & 0.000000 & 0 \\
# rpoB_H445C & 42.000000 & 0.4 & 5.000000 & 1.4 & 0.000000 & 0 \\
# rpoB_S441L & 30.000000 & 0.3 & 3.000000 & 0.8 & 1.000000 & 2.2 \\
# rpoB_Q432P & 24.000000 & 0.2 & 8.000000 & 2.3 & 0.000000 & 0 \\
# rpoB_L430R & 24.000000 & 0.2 & 1.000000 & 0.3 & 0.000000 & 0 \\
# rpoB_Q432L & 21.000000 & 0.2 & 1.000000 & 0.3 & 2.000000 & 4.4 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# Here minor RAV/ heterogeneous sample means any variant/ sample with less than 0.90 read support; so what is the distribution of the FRS?

# %%
variant_count_all = samples_with_dst[(~samples_with_dst.HAS_MAJOR_RAV) & (samples_with_dst.HAS_MINOR_RAV) & (samples_with_dst.MAX_RAV_FRS<1) & (samples_with_dst.MAX_RAV_FRS>=0.05)]
plot_frs_histogram(variant_count_all, savefig=True)

# %%
print("There are", variant_count_all.shape[0], "samples with a minor RAV and no major RAVs, and 0.05<= FRS < 0.9")
# Out:
# There are 258 samples with a minor RAV and no major RAVs, and 0.05<= FRS < 0.9

# %% [markdown]
# ## Influence of FRS threshold on rifampicin resistance prediction
#
# Let's therefore change the definition of what is a resistance associated variant by altering the FRS which leads to it being classified and therefore predicting resistance.
#
# We will store the results in a `pandas.DataFrame` so we can later plot graphs etc.

# %%
for i in range(5, 100, 5):
    cutoff = i / 100
    df = samples_with_dst.copy() 
    df['HAS_RESISTANT_MUTATION'] = ((df['MAX_RAV_FRS'] >= cutoff) & (df.HAS_MINOR_RAV)) | (df.HAS_MAJOR_RAV)
    a = calculate_results_row(df, description='scan FRS', min_FRS=cutoff)
    if i == 5:
        results_table = pd.DataFrame(a).T
    else:
        results_table = pd.concat([results_table,pd.DataFrame(a).T])

results_table
# Out:
#   description min_FRS     TP   FP      P     TN   FN      N sensitivity
# 0    scan FRS    0.05  10036  529  10410  24599  374  25128    0.964073  \
# 0    scan FRS     0.1  10035  528  10410  24600  375  25128    0.963977
# 0    scan FRS    0.15  10028  526  10410  24602  382  25128    0.963305
# 0    scan FRS     0.2  10020  514  10410  24614  390  25128    0.962536
# 0    scan FRS    0.25  10013  512  10410  24616  397  25128    0.961864
# 0    scan FRS     0.3  10006  508  10410  24620  404  25128    0.961191
# 0    scan FRS    0.35  10003  506  10410  24622  407  25128    0.960903
# 0    scan FRS     0.4  10000  502  10410  24626  410  25128    0.960615
# 0    scan FRS    0.45   9991  502  10410  24626  419  25128     0.95975
# 0    scan FRS     0.5   9982  502  10410  24626  428  25128    0.958886
# 0    scan FRS    0.55   9972  502  10410  24626  438  25128    0.957925
# 0    scan FRS     0.6   9957  500  10410  24628  453  25128    0.956484
# 0    scan FRS    0.65   9940  496  10410  24632  470  25128    0.954851
# 0    scan FRS     0.7   9923  496  10410  24632  487  25128    0.953218
# 0    scan FRS    0.75   9908  496  10410  24632  502  25128    0.951777
# 0    scan FRS     0.8   9886  495  10410  24633  524  25128    0.949664
# 0    scan FRS    0.85   9853  493  10410  24635  557  25128    0.946494
# 0    scan FRS     0.9   9819  488  10410  24640  591  25128    0.943228
# 0    scan FRS    0.95   9819  488  10410  24640  591  25128    0.943228
#
#   specificity       PPV       NPV sensitivity_error specificity_error
# 0    0.978948  0.949929  0.985024          0.001775          0.003575  \
# 0    0.978988  0.950014  0.984985          0.001773           0.00358
# 0    0.979067  0.950161   0.98471           0.00177          0.003612
# 0    0.979545  0.951206  0.984402           0.00175          0.003648
# 0    0.979624  0.951354  0.984128          0.001747          0.003679
# 0    0.979784  0.951683  0.983855           0.00174           0.00371
# 0    0.979863  0.951851  0.983739          0.001737          0.003723
# 0    0.980022    0.9522  0.983624           0.00173          0.003736
# 0    0.980022  0.952159   0.98327           0.00173          0.003776
# 0    0.980022  0.952118  0.982917           0.00173          0.003814
# 0    0.980022  0.952072  0.982525           0.00173          0.003857
# 0    0.980102  0.952185  0.981939          0.001727          0.003919
# 0    0.980261  0.952472  0.981276           0.00172          0.003989
# 0    0.980261  0.952395  0.980612           0.00172          0.004057
# 0    0.980261  0.952326  0.980027           0.00172          0.004115
# 0    0.980301  0.952317  0.979171          0.001718            0.0042
# 0     0.98038  0.952349   0.97789          0.001715          0.004323
# 0    0.980579  0.952654  0.976576          0.001706          0.004445
# 0    0.980579  0.952654  0.976576          0.001706          0.004445
#
#   PPV_error NPV_error
# 0  0.004159  0.001506
# 0  0.004156  0.001508
# 0  0.004152  0.001522
# 0  0.004114  0.001536
# 0   0.00411  0.001549
# 0  0.004099  0.001562
# 0  0.004093  0.001567
# 0   0.00408  0.001572
# 0  0.004084  0.001588
# 0  0.004087  0.001605
# 0  0.004091  0.001622
# 0   0.00409  0.001648
# 0  0.004082  0.001677
# 0  0.004089  0.001705
# 0  0.004094   0.00173
# 0  0.004099  0.001765
# 0  0.004105  0.001816
# 0    0.0041  0.001866
# 0    0.0041  0.001866

# %%
# plot the performance as we alter the minimum FRS
df = results_table.copy()
df = df[df.description=='scan FRS']

plot_performance_frs(df, save_figure=True, metrics=['sensitivity', 'specificity'], colours=["#ff7f0e", "#1f77b4"], save_name='fig-frs-sensitivity-specificity')
plot_performance_frs(df, save_figure=True, metrics=['PPV', 'NPV'], colours=['#984ea3', '#4daf4a'], save_name='fig-frs-ppv-npv')

# %% [markdown]
# Quantify strength of correlation with FRS of the different metrics by performing a linear regression and evaluating the slope

# %%
from scipy import stats
def plot_regression(df, metric):
    """
    Perform linear regression and plot results for the given metric.
    
    Parameters:
    df (pd.DataFrame): Dataframe containing 'min_FRS' and the specified metric.
    metric (str): The metric to analyze ('sensitivity', 'specificity', 'PPV', 'NPV').
    """
    slope, intercept, r_value, p_value, std_err = stats.linregress(df['min_FRS'].to_list(), df[metric].to_list())
    
    print(f"{metric.capitalize()}:")
    print(f"Slope: {slope}, Intercept: {intercept}, R-value: {r_value}, P-value: {p_value}, Std Error: {std_err}\n")
    
    plt.figure(figsize=(8, 6))
    plt.scatter(df['min_FRS'], df[metric], label='Data Points', color='blue')
    plt.plot(df['min_FRS'], slope * df['min_FRS'] + intercept, color='red', label='Best Fit Line')
    plt.xlabel('Minimum FRS')
    plt.ylabel(metric.capitalize())
    plt.title(f'{metric.capitalize()} vs Minimum FRS')
    plt.legend()
    plt.show()

def analyze_all_metrics(df):
    """
    Perform regression analysis for all four metrics and plot results.
    
    Parameters:
    df (pd.DataFrame): Dataframe containing 'min_FRS' and the four metrics.
    """
    metrics = ['sensitivity', 'specificity', 'PPV', 'NPV']
    for metric in metrics:
        plot_regression(df, metric)

analyze_all_metrics(df)
# Out:
# Sensitivity:
# Slope: -0.023125537185904217, Intercept: 0.968087365387532, R-value: -0.9545803457457126, P-value: 2.2847855986068507e-10, Std Error: 0.0017506670449635722
# Specificity:
# Slope: 0.0016700458564430768, Intercept: 0.9790930087076973, R-value: 0.9459586274755925, P-value: 9.718961848378463e-10, Std Error: 0.0001388550821317376
# Ppv:
# Slope: 0.002704196453492703, Intercept: 0.9504424357322622, R-value: 0.8733423185049517, P-value: 1.0517038628435149e-06, Std Error: 0.00036580834813638226
# Npv:
# Slope: -0.009382795932483801, Intercept: 0.9866517769639686, R-value: -0.9549225425938079, P-value: 2.145043492304085e-10, Std Error: 0.0007074310988884425

# %% [markdown]
# Since sensitivity appears to rise let's compare two concrete cases so we can quantify the improvement using a p-value

# %%
df = copy.deepcopy(samples_with_dst)
df['HAS_RESISTANT_MUTATION'] = ((df['MAX_RAV_FRS'] >= 0.05) & (df.HAS_MINOR_RAV)) | (df.HAS_MAJOR_RAV)
a = calculate_results_row(df, description='bar chart', min_FRS=0.05)
results_table = pd.concat([results_table,pd.DataFrame(a).T])

samples_major_only = samples_with_dst.copy()
samples_major_only['HAS_RESISTANT_MUTATION'] = (samples_major_only['HAS_MAJOR_RAV']) #| ((samples_major_only['MAX_RAV_FRS'] >= 0.90) & (df.HAS_MINOR_RAV)) #without this the bar and FRS scan values are different 
b = calculate_results_row(samples_major_only, description='bar chart', min_FRS=0.90)
results_table = pd.concat([results_table,pd.DataFrame(b).T])

results_table = results_table.sort_values('min_FRS', ascending=False)
results_table
# Out:
#   description min_FRS     TP   FP      P     TN   FN      N sensitivity
# 0    scan FRS    0.95   9819  488  10410  24640  591  25128    0.943228  \
# 0   bar chart     0.9   9819  488  10410  24640  591  25128    0.943228
# 0    scan FRS     0.9   9819  488  10410  24640  591  25128    0.943228
# 0    scan FRS    0.85   9853  493  10410  24635  557  25128    0.946494
# 0    scan FRS     0.8   9886  495  10410  24633  524  25128    0.949664
# 0    scan FRS    0.75   9908  496  10410  24632  502  25128    0.951777
# 0    scan FRS     0.7   9923  496  10410  24632  487  25128    0.953218
# 0    scan FRS    0.65   9940  496  10410  24632  470  25128    0.954851
# 0    scan FRS     0.6   9957  500  10410  24628  453  25128    0.956484
# 0    scan FRS    0.55   9972  502  10410  24626  438  25128    0.957925
# 0    scan FRS     0.5   9982  502  10410  24626  428  25128    0.958886
# 0    scan FRS    0.45   9991  502  10410  24626  419  25128     0.95975
# 0    scan FRS     0.4  10000  502  10410  24626  410  25128    0.960615
# 0    scan FRS    0.35  10003  506  10410  24622  407  25128    0.960903
# 0    scan FRS     0.3  10006  508  10410  24620  404  25128    0.961191
# 0    scan FRS    0.25  10013  512  10410  24616  397  25128    0.961864
# 0    scan FRS     0.2  10020  514  10410  24614  390  25128    0.962536
# 0    scan FRS    0.15  10028  526  10410  24602  382  25128    0.963305
# 0    scan FRS     0.1  10035  528  10410  24600  375  25128    0.963977
# 0   bar chart    0.05  10036  529  10410  24599  374  25128    0.964073
# 0    scan FRS    0.05  10036  529  10410  24599  374  25128    0.964073
#
#   specificity       PPV       NPV sensitivity_error specificity_error
# 0    0.980579  0.952654  0.976576          0.001706          0.004445  \
# 0    0.980579  0.952654  0.976576          0.001706          0.004445
# 0    0.980579  0.952654  0.976576          0.001706          0.004445
# 0     0.98038  0.952349   0.97789          0.001715          0.004323
# 0    0.980301  0.952317  0.979171          0.001718            0.0042
# 0    0.980261  0.952326  0.980027           0.00172          0.004115
# 0    0.980261  0.952395  0.980612           0.00172          0.004057
# 0    0.980261  0.952472  0.981276           0.00172          0.003989
# 0    0.980102  0.952185  0.981939          0.001727          0.003919
# 0    0.980022  0.952072  0.982525           0.00173          0.003857
# 0    0.980022  0.952118  0.982917           0.00173          0.003814
# 0    0.980022  0.952159   0.98327           0.00173          0.003776
# 0    0.980022    0.9522  0.983624           0.00173          0.003736
# 0    0.979863  0.951851  0.983739          0.001737          0.003723
# 0    0.979784  0.951683  0.983855           0.00174           0.00371
# 0    0.979624  0.951354  0.984128          0.001747          0.003679
# 0    0.979545  0.951206  0.984402           0.00175          0.003648
# 0    0.979067  0.950161   0.98471           0.00177          0.003612
# 0    0.978988  0.950014  0.984985          0.001773           0.00358
# 0    0.978948  0.949929  0.985024          0.001775          0.003575
# 0    0.978948  0.949929  0.985024          0.001775          0.003575
#
#   PPV_error NPV_error
# 0    0.0041  0.001866
# 0    0.0041  0.001866
# 0    0.0041  0.001866
# 0  0.004105  0.001816
# 0  0.004099  0.001765
# 0  0.004094   0.00173
# 0  0.004089  0.001705
# 0  0.004082  0.001677
# 0   0.00409  0.001648
# 0  0.004091  0.001622
# 0  0.004087  0.001605
# 0  0.004084  0.001588
# 0   0.00408  0.001572
# 0  0.004093  0.001567
# 0  0.004099  0.001562
# 0   0.00411  0.001549
# 0  0.004114  0.001536
# 0  0.004152  0.001522
# 0  0.004156  0.001508
# 0  0.004159  0.001506
# 0  0.004159  0.001506

# %%
df = results_table[results_table.description=='bar chart']

plot_histogram(df, save_figure=True, metrics=['sensitivity', 'specificity'], colours=["#ff7f0e", "#1f77b4"], save_name='bar-sens-spec')
plot_histogram(df, save_figure=True, metrics=['PPV', 'NPV'], colours=['#984ea3', '#4daf4a'], save_name='bar-ppv-npv')
# Out:
# sensitivity -7.153218549280425 8.476648358178581e-13
# NPV -6.892489751612033 5.482424297974661e-12
#  -6.892489751612033 5.482424297974661e-12

# %% [markdown]
# ## Using compensatory mutations for resistant prediction
#
# Now let's describe the presence/distribution of compensatory mutations in the dataset

# %%
print(f"Of the {len(samples_with_dst)} samples with genetics and DST there are {samples_with_dst.HAS_COMPENSATORY_MUTATION.sum()} with at least one compensatory mutation at any level of read support")

print(f"Of these {(samples_with_dst.HAS_MAJOR_CM & ~samples_with_dst.HAS_MINOR_CM).sum()} samples only have ≥1 homogeneous CM whilst {(~samples_with_dst.HAS_MAJOR_CM & samples_with_dst.HAS_MINOR_CM).sum()} only have ≥1 minor CM and {(samples_with_dst.HAS_MAJOR_CM & samples_with_dst.HAS_MINOR_CM).sum()} have ≥1 of both")
# Out:
# Of the 35538 samples with genetics and DST there are 4678 with at least one compensatory mutation at any level of read support
# Of these 4289 samples only have ≥1 homogeneous CM whilst 384 only have ≥1 minor CM and 5 have ≥1 of both

# %% [markdown]
# As expected, most of the 4289 samples with at least one major CM also have a RAV (this being how the CMs were identified). A few samples have two compensatory mutations.

# %%
df = samples_with_dst[(samples_with_dst.HAS_MAJOR_CM & ~samples_with_dst.HAS_MINOR_CM)]
pd.crosstab(df.N_RAV, df.N_CM)
# Out:
# N_CM    1.0  2.0
# N_RAV
# 0.0      11    0
# 1.0    4269    3
# 2.0       5    0
# 3.0       1    0

# %% [markdown]
# And most of the 384 samples that have a subpopulation containing one or more CMs are also associated with a RAV. Those that are not overhwlemingly show the CM rpoC_F452L

# %%
df = samples_with_dst[(~samples_with_dst.HAS_MAJOR_CM & samples_with_dst.HAS_MINOR_CM)]
pd.crosstab(df.N_RAV, df.N_CM)
# Out:
# N_CM   1.0  2.0  3.0  4.0
# N_RAV
# 0.0    134    0    0    0
# 1.0    183   45    3    2
# 2.0     14    3    0    0

# %%
outliers = df[df.HAS_RESISTANT_MUTATION == False].index.to_list()
outliers
mutations[mutations.index.isin(outliers) & (mutations.IS_COMPENSATORY_MUTATION)].GENE_MUTATION.value_counts()
# Out:
# GENE_MUTATION
# rpoC_F452L    132
# rpoC_V483A      1
# rpoC_G433S      1
# Name: count, dtype: int64

# %%
df = copy.deepcopy(samples_with_dst)
df['HAS_RESISTANT_MUTATION'] = (df.HAS_MAJOR_RAV) | (df.HAS_MAJOR_CM)
a = calculate_results_row(df, description='with major compensatory', min_FRS=0.90)
results_table = pd.concat([results_table,pd.DataFrame(a).T])

df = copy.deepcopy(samples_with_dst)
df['HAS_RESISTANT_MUTATION'] = ((df.MAX_RAV_FRS>0.05) & (df.HAS_RESISTANT_MUTATION)) | ((df.MAX_CM_FRS>0.05) & (df.HAS_COMPENSATORY_MUTATION))
a = calculate_results_row(df, description='with minor compensatory', min_FRS=0.05)
results_table = pd.concat([results_table,pd.DataFrame(a).T])

df = copy.deepcopy(samples_with_dst)
df['HAS_RESISTANT_MUTATION'] = (df.MAX_CM_FRS>0.05) & ((df.HAS_COMPENSATORY_MUTATION))
a = calculate_results_row(df, description='minor compensatory only', min_FRS=0.05)
results_table = pd.concat([results_table,pd.DataFrame(a).T])

df = copy.deepcopy(samples_with_dst)
df['HAS_RESISTANT_MUTATION'] = (df.MAX_CM_FRS>0.90) & ((df.HAS_COMPENSATORY_MUTATION))
a = calculate_results_row(df, description='major compensatory only', min_FRS=0.90)
results_table = pd.concat([results_table,pd.DataFrame(a).T])

results_table
# Out:
#                description min_FRS     TP   FP      P     TN    FN      N
# 0                 scan FRS    0.95   9819  488  10410  24640   591  25128  \
# 0                bar chart     0.9   9819  488  10410  24640   591  25128
# 0                 scan FRS     0.9   9819  488  10410  24640   591  25128
# 0                 scan FRS    0.85   9853  493  10410  24635   557  25128
# 0                 scan FRS     0.8   9886  495  10410  24633   524  25128
# 0                 scan FRS    0.75   9908  496  10410  24632   502  25128
# 0                 scan FRS     0.7   9923  496  10410  24632   487  25128
# 0                 scan FRS    0.65   9940  496  10410  24632   470  25128
# 0                 scan FRS     0.6   9957  500  10410  24628   453  25128
# 0                 scan FRS    0.55   9972  502  10410  24626   438  25128
# 0                 scan FRS     0.5   9982  502  10410  24626   428  25128
# 0                 scan FRS    0.45   9991  502  10410  24626   419  25128
# 0                 scan FRS     0.4  10000  502  10410  24626   410  25128
# 0                 scan FRS    0.35  10003  506  10410  24622   407  25128
# 0                 scan FRS     0.3  10006  508  10410  24620   404  25128
# 0                 scan FRS    0.25  10013  512  10410  24616   397  25128
# 0                 scan FRS     0.2  10020  514  10410  24614   390  25128
# 0                 scan FRS    0.15  10028  526  10410  24602   382  25128
# 0                 scan FRS     0.1  10035  528  10410  24600   375  25128
# 0                bar chart    0.05  10036  529  10410  24599   374  25128
# 0                 scan FRS    0.05  10036  529  10410  24599   374  25128
# 0  with major compensatory     0.9   9842  490  10410  24638   568  25128
# 0  with minor compensatory    0.05  10047  663  10410  24465   363  25128
# 0  minor compensatory only    0.05   4452  225  10410  24903  5958  25128
# 0  major compensatory only     0.9   4221   73  10410  25055  6189  25128
#
#   sensitivity specificity       PPV       NPV sensitivity_error
# 0    0.943228    0.980579  0.952654  0.976576          0.001706  \
# 0    0.943228    0.980579  0.952654  0.976576          0.001706
# 0    0.943228    0.980579  0.952654  0.976576          0.001706
# 0    0.946494     0.98038  0.952349   0.97789          0.001715
# 0    0.949664    0.980301  0.952317  0.979171          0.001718
# 0    0.951777    0.980261  0.952326  0.980027           0.00172
# 0    0.953218    0.980261  0.952395  0.980612           0.00172
# 0    0.954851    0.980261  0.952472  0.981276           0.00172
# 0    0.956484    0.980102  0.952185  0.981939          0.001727
# 0    0.957925    0.980022  0.952072  0.982525           0.00173
# 0    0.958886    0.980022  0.952118  0.982917           0.00173
# 0     0.95975    0.980022  0.952159   0.98327           0.00173
# 0    0.960615    0.980022    0.9522  0.983624           0.00173
# 0    0.960903    0.979863  0.951851  0.983739          0.001737
# 0    0.961191    0.979784  0.951683  0.983855           0.00174
# 0    0.961864    0.979624  0.951354  0.984128          0.001747
# 0    0.962536    0.979545  0.951206  0.984402           0.00175
# 0    0.963305    0.979067  0.950161   0.98471           0.00177
# 0    0.963977    0.978988  0.950014  0.984985          0.001773
# 0    0.964073    0.978948  0.949929  0.985024          0.001775
# 0    0.964073    0.978948  0.949929  0.985024          0.001775
# 0    0.945437      0.9805  0.952575  0.977466           0.00171
# 0     0.96513    0.973615  0.938095  0.985379          0.001982
# 0    0.427666    0.991046  0.951892  0.806941          0.001165
# 0    0.405476    0.997095     0.983  0.801914          0.000665
#
#   specificity_error PPV_error NPV_error
# 0          0.004445    0.0041  0.001866
# 0          0.004445    0.0041  0.001866
# 0          0.004445    0.0041  0.001866
# 0          0.004323  0.004105  0.001816
# 0            0.0042  0.004099  0.001765
# 0          0.004115  0.004094   0.00173
# 0          0.004057  0.004089  0.001705
# 0          0.003989  0.004082  0.001677
# 0          0.003919   0.00409  0.001648
# 0          0.003857  0.004091  0.001622
# 0          0.003814  0.004087  0.001605
# 0          0.003776  0.004084  0.001588
# 0          0.003736   0.00408  0.001572
# 0          0.003723  0.004093  0.001567
# 0           0.00371  0.004099  0.001562
# 0          0.003679   0.00411  0.001549
# 0          0.003648  0.004114  0.001536
# 0          0.003612  0.004152  0.001522
# 0           0.00358  0.004156  0.001508
# 0          0.003575  0.004159  0.001506
# 0          0.003575  0.004159  0.001506
# 0          0.004363  0.004098  0.001832
# 0          0.003524  0.004564  0.001493
# 0          0.009504  0.006133  0.004404
# 0          0.009432  0.003867  0.004419

# %%
# Extract data from results table for FNR/FPR comparison
# With FRS Cutoff No CMs (min_FRS=0.900)
TP_noCM, FN_noCM = 9819, 591
TN_noCM, FP_noCM = 24640, 488

# Low FRS Cutoff With CMs (min_FRS=0.050 with compensatory mutations excl. rpoC_F452L)
TP_CM, FN_CM = 10047, 363
TN_CM, FP_CM = 24597, 531

# Calculate FNR and FPR for both scenarios
FNR_noCM = FN_noCM / (FN_noCM + TP_noCM)   # False Negative Rate
FPR_noCM = FP_noCM / (FP_noCM + TN_noCM)   # False Positive Rate

FNR_CM = FN_CM / (FN_CM + TP_CM)           # False Negative Rate with CMs
FPR_CM = FP_CM / (FP_CM + TN_CM)           # False Positive Rate with CMs

x = np.arange(2)  # 0 = FNR, 1 = FPR
bar_width = 0.35

fig, ax = plt.subplots(figsize=(6, 6))

# Colors
teal = '#2ca25f'  # FNR
purple = '#756bb1'  # FPR

# Values
filled_values = [FNR_noCM, FPR_noCM]     # With FRS cutoff, no CMs
hollow_values = [FNR_CM, FPR_CM]         # Low FRS cutoff with CMs

# Labels
labels_filled = ['With FRS cutoff\nno CMs', '']
labels_hollow = ['Low FRS cutoff\nwith CMs', '']

bars_filled = ax.bar(x - bar_width/2, filled_values, width=bar_width,
                     color=[teal, purple], edgecolor=[teal, purple])

bars_hollow = ax.bar(x + bar_width/2, hollow_values, width=bar_width,
                     color='white', edgecolor=[teal, purple], linewidth=1.5)

# Add % labels on top
for bar, val in zip(list(bars_filled) + list(bars_hollow), filled_values + hollow_values):
    ax.text(bar.get_x() + bar.get_width()/2, val + 0.002,
            f'{val * 100:.2f}%', ha='center', va='bottom', fontsize=12)

# Labels inside FNR bars
for i in range(2):  # 0 = FNR, 1 = FPR
    if labels_filled[i]:
        bar = bars_filled[i]
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height()/2,
                labels_filled[i], ha='center', va='center', rotation=90,
                fontsize=10, color='white', fontweight='bold')
    if labels_hollow[i]:
        bar = bars_hollow[i]
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height()/2,
                labels_hollow[i], ha='center', va='center', rotation=90,
                fontsize=10, color='black', fontweight='bold')

ax.set_xticks(x)
ax.set_xticklabels(['False Negative Rate', 'False Positive Rate'], fontsize=12)
ax.set_ylim(0, 0.07)  # Adjust based on actual values
ax.set_ylabel('%', fontsize=12)

yticks = ax.get_yticks()
ax.set_yticklabels([f'{int(t * 100)}' for t in yticks], fontsize=14)

ax.spines[['right', 'top']].set_visible(False)
ax.tick_params(axis='both', labelsize=12)

def add_star(ax, xpos1, xpos2, height, text='ns'):
    y = height + 0.01
    ax.plot([xpos1, xpos1, xpos2, xpos2], [height+0.008, y, y, height+0.008], lw=1.5, color='black')
    ax.text((xpos1 + xpos2)/2, y + 0.002, text, ha='center', va='bottom', fontsize=12)

# Fisher's exact test for significance
from scipy.stats import fisher_exact

# For FNR: [TP, FN]
table_fnr = [[TP_noCM, FN_noCM], [TP_CM, FN_CM]]

# For FPR: [TN, FP]
table_fpr = [[TN_noCM, FP_noCM], [TN_CM, FP_CM]]

_, p_fnr = fisher_exact(table_fnr)
_, p_fpr = fisher_exact(table_fpr)

# Determine significance levels
def get_significance_label(p_value):
    if p_value < 0.001:
        return '***'
    elif p_value < 0.01:
        return '**'
    elif p_value < 0.05:
        return '*'
    else:
        return 'ns'

# Add significance indicators with actual p-values
add_star(ax, x[0] - bar_width/2, x[0] + bar_width/2, max(FNR_noCM, FNR_CM), text=get_significance_label(p_fnr))
add_star(ax, x[1] - bar_width/2, x[1] + bar_width/2, max(FPR_noCM, FPR_CM), text=get_significance_label(p_fpr))

print(f"\nFisher's Exact Test:")
print(f"  FNR p-value: {p_fnr:.2e}")
print(f"  FPR p-value: {p_fpr:.2e}")

plt.tight_layout()

# Save figure in high resolution
plt.savefig('FNR_FPR_comparison_both.svg', format='svg', dpi=1200, bbox_inches='tight')

plt.show()
# Out:
# Fisher's Exact Test:
#   FNR p-value: 4.10e-14
#   FPR p-value: 1.84e-01
#
#   FNR p-value: 4.10e-14
#   FPR p-value: 1.84e-01
# /var/folders/_3/8y_dwngx2614_y_52fzh1c4w0000gn/T/ipykernel_30567/2640548961.py:64: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([f'{int(t * 100)}' for t in yticks], fontsize=14)

# %% [markdown]
# Summarise all findings on sensitivity, specificity etc in Table 1

# %%
table_1 = results_table 
table_1 = table_1[table_1.description != 'scan FRS']
table_1.drop(['P','N'], axis = 1, inplace = True)
table_1.to_latex(index=False,
                  float_format="{:.3f}".format)
# Out:
# /var/folders/_3/8y_dwngx2614_y_52fzh1c4w0000gn/T/ipykernel_30567/988324575.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table_1.drop(['P','N'], axis = 1, inplace = True)
# '\\begin{tabular}{llllllllllllll}\n\\toprule\ndescription & min_FRS & TP & FP & TN & FN & sensitivity & specificity & PPV & NPV & sensitivity_error & specificity_error & PPV_error & NPV_error \\\\\n\\midrule\nbar chart & 0.900 & 9819 & 488 & 24640 & 591 & 0.943 & 0.981 & 0.953 & 0.977 & 0.002 & 0.004 & 0.004 & 0.002 \\\\\nbar chart & 0.050 & 10036 & 529 & 24599 & 374 & 0.964 & 0.979 & 0.950 & 0.985 & 0.002 & 0.004 & 0.004 & 0.002 \\\\\nwith major compensatory & 0.900 & 9842 & 490 & 24638 & 568 & 0.945 & 0.980 & 0.953 & 0.977 & 0.002 & 0.004 & 0.004 & 0.002 \\\\\nwith minor compensatory & 0.050 & 10047 & 663 & 24465 & 363 & 0.965 & 0.974 & 0.938 & 0.985 & 0.002 & 0.004 & 0.005 & 0.001 \\\\\nminor compensatory only & 0.050 & 4452 & 225 & 24903 & 5958 & 0.428 & 0.991 & 0.952 & 0.807 & 0.001 & 0.010 & 0.006 & 0.004 \\\\\nmajor compensatory only & 0.900 & 4221 & 73 & 25055 & 6189 & 0.405 & 0.997 & 0.983 & 0.802 & 0.001 & 0.009 & 0.004 & 0.004 \\\\\n\\bottomrule\n\\end{tabular}\n'

# %% [markdown]
# ## Examine compensation levels in heterogeneous vs homogeneous resistant samples
#
# Plot the amount of compensation in homogeneous vs heterogeneous samples

# %%
major_samples = samples[(~samples.HAS_MINOR_RAV) & (samples.HAS_MAJOR_RAV)]
minor_samples = samples[(samples.HAS_MINOR_RAV) & (~samples.HAS_MAJOR_RAV)]

major_prop_CM = (major_samples.HAS_COMPENSATORY_MUTATION & major_samples.MAX_CM_FRS>=0.05).sum()/len(major_samples)
minor_prop_CM = (minor_samples.HAS_COMPENSATORY_MUTATION & minor_samples.MAX_CM_FRS>=0.05).sum()/len(minor_samples)

plot_compensation_barplot(major_prop_CM, minor_prop_CM, save_name='bar-compensatory-frs', save_figure=True)

# %%
samples_copy = copy.deepcopy(samples)
samples_copy = samples_copy[~(samples_copy['HAS_MINOR_RAV'] & samples_copy['HAS_MAJOR_RAV'])]
samples_copy = samples_copy[~(~(samples_copy['HAS_MINOR_RAV']) & ~(samples_copy['HAS_MAJOR_RAV']))]
samples_copy['FRS_CM'] = (samples_copy['HAS_COMPENSATORY_MUTATION']) #& (samples_copy['MAX_CM_FRS'] > 0.05)

contingency = pd.crosstab(samples_copy.HAS_MINOR_RAV,samples_copy.FRS_CM)
print(contingency)

odds_ratio, p_value = fisher_exact(contingency)
print("The fishers exact p-value for the association of CMs with the sample type homogenous vs heterogeneous is {:.2e}".format(p_value))
# Out:
# FRS_CM         False  True
# HAS_MINOR_RAV
# False           7646   5887
# True             244    127
# The fishers exact p-value for the association of CMs with the sample type homogenous vs heterogeneous is 3.63e-04

# %%
minor_samples_with_CM = minor_samples[minor_samples.HAS_COMPENSATORY_MUTATION & (minor_samples.MAX_CM_FRS<0.9)]
print(f"There are {len(minor_samples_with_CM)} minor RAV samples with a minor compensatory mutation")
# Out:
# There are 104 minor RAV samples with a minor compensatory mutation

# %% [markdown]
# If we are to look at the correlation between the FRS for the RAVs and CMs, we need to exclude any samples with multiple mutations as these are likely to be more complex mixtures.

# %%
pd.crosstab(minor_samples_with_CM.N_RAV, minor_samples_with_CM.N_CM)
# Out:
# N_CM   1.0  2.0
# N_RAV
# 1.0     79    1
# 2.0     20    3
# 3.0      1    0

# %%
df = minor_samples_with_CM[(minor_samples_with_CM.N_RAV==1) & (minor_samples_with_CM.N_CM==1)]

import scipy.stats as stats

# Calculate Pearson correlation coefficient and p-value
corr_coeff, p_value = stats.pearsonr(df['MAX_RAV_FRS'], df['MAX_CM_FRS'])

# Print the results
print(f"Pearson correlation coefficient: {corr_coeff:.4f}")
print(f"P-value: {p_value:.4e}")

axis = df.plot('MAX_RAV_FRS', 'MAX_CM_FRS', kind='scatter', color='#e41a1c', s=10, figsize=(2.5,2.5))
figure = axis.get_figure()
axis.plot([0, 0.9], [0, 0.9], color='grey', lw=1)
axis.set_xlim(0,0.9)
axis.set_ylim(0,0.9)
axis.set_xticks(np.arange(0,0.9,0.2))
axis.set_yticks(np.arange(0,0.9,0.2))
axis.set_xlabel('Fraction of reads supporting RAV')
axis.set_ylabel('Fraction of reads supporting CM')

# Calculate the line of best fit
slope, intercept = np.polyfit(df['MAX_RAV_FRS'], df['MAX_CM_FRS'], 1)  # Linear regression
line_x = np.linspace(df['MAX_RAV_FRS'].min(), df['MAX_RAV_FRS'].max(), 100)
line_y = slope * line_x + intercept

# Plot the regression line
# plt.plot(line_x, line_y, color='blue', linewidth=1, label=f"y = {slope:.2f}x + {intercept:.2f}")

# remove unnecessary spines
axis.spines["top"].set_visible(False)
axis.spines["right"].set_visible(False)

figure.savefig('pdf/fig-cm-rav-fraction-reads.pdf', bbox_inches='tight', transparent=True)
# Out:
# Pearson correlation coefficient: 0.8437
# P-value: 1.6870e-22

# %% [markdown]
# ## Genetic variation in heterogeneous samples with resistant subpopulations
#
# Look at genetic variation to get insight into source of resistance (within-host evolution or secondary infection)

# %%
res_minor_uniqueids = samples[(samples['HAS_MINOR_RAV']) & (~samples['HAS_MAJOR_RAV'])].index
print(len(res_minor_uniqueids), 'samples show at least one RAV in a subpopulation and no RAV in over 90 % of the population')
# Out:
# 371 samples show at least one RAV in a subpopulation and no RAV in over 90 % of the population

# %% [markdown]
# We need to inspect these 371 samples to check if there is more than one RAV per sample with a resistant subpopulation.

# %%
effects_subset = effects[effects.UNIQUEID.isin(res_minor_uniqueids)]
summary_rif = effects_subset[['UNIQUEID', 'MUTATION']].groupby('UNIQUEID').count()
summary_rif.MUTATION.value_counts()
# Out:
# MUTATION
# 1    248
# 2     95
# 3     13
# 4      1
# Name: count, dtype: int64

# %% [markdown]
# We see some samples with more than one RIV RAF at < 0.90 FRS. We will only look at the samples which have exactly one minor RIF RAV, otherwise we will not know if both of these mutations are in the same subpopulation

# %%
solo_rif = summary_rif[summary_rif.MUTATION==1]
solo_rif_effects = effects[effects.UNIQUEID.isin(solo_rif.index)]
solo_rif_effects['MUTATION'] = solo_rif_effects['MUTATION'].str.replace(r':.*', '', regex=True)
solo_rif_effects.set_index(['UNIQUEID','MUTATION'], inplace=True)
solo_rif_effects.index[:3]

#save the solo_rif_effects to csv for later to subset down our mutations table
solo_rif_effects.to_csv('data/cryptic_3/solo_rif_effects.csv')
# Out:
# /var/folders/_3/8y_dwngx2614_y_52fzh1c4w0000gn/T/ipykernel_30567/285981622.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   solo_rif_effects['MUTATION'] = solo_rif_effects['MUTATION'].str.replace(r':.*', '', regex=True)

# %% [markdown]
# Now we need to reload the mutations table since we had it filtered to only RNAP mutations. This new `mutations` table contains all mutations called in the 248 samples with one RIF RAV at < 0.90 FRS. We ignore mutations that are RIF mutations themselves.

# %%
mutations = pd.read_parquet('data/cryptic_3/RES_MINOR_MUTATIONS.parquet', engine='pyarrow')

mutations['GENE_MUTATION'] = np.where(
    mutations['IS_MINOR'],  # Condition: if IS_MINOR_ALLELE is True
    mutations['GENE'].astype(str) + '_' + mutations['MINOR_MUTATION'].astype(str),  # Then: use GENE + MINOR_MUTATION
    mutations['GENE'].astype(str) + '_' + mutations['MUTATION'].astype(str)  # Else: use GENE + MUTATION
)

mutations.set_index(['UNIQUEID','MINOR_MUTATION'], inplace=True)

solo_rif_mutations = mutations[mutations.index.isin(solo_rif_effects.index)]
solo_rif_mutations.reset_index(inplace=True)
solo_rif_mutations.set_index(['UNIQUEID','GENE','GENE_POSITION'], inplace=True)
solo_rif_mutations

mutations.reset_index(inplace=True)
solo_mutations = mutations[mutations.UNIQUEID.isin(solo_rif.index)]
solo_mutations.set_index(['UNIQUEID','GENE','GENE_POSITION'],inplace=True)

# don't forget to ignore the solo rif mutations themselves
solo_other_mutations = solo_mutations[~solo_mutations.index.isin(solo_rif_mutations.index)]
solo_other_mutations
# Out:
#                                                                         MINOR_MUTATION
# UNIQUEID                                           GENE   GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE1     485.0                   NaN  \
#                                                    PE14    106.0                   NaN
#                                                    PE16    96.0                    NaN
#                                                    PE23    282.0                   NaN
#                                                            344.0                   NaN
# ...                                                                                ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... vapC47  46.0                    NaN
#                                                    whiB6  -75.0                    NaN
#                                                    yrbE2A  111.0                   NaN
#                                                            160.0                   NaN
#                                                    zwf1   -14.0                    NaN
#
#                                                                           MUTATION
# UNIQUEID                                           GENE   GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE1     485.0             L485L  \
#                                                    PE14    106.0             A106A
#                                                    PE16    96.0               A96A
#                                                    PE23    282.0             S282R
#                                                            344.0             A344T
# ...                                                                            ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... vapC47  46.0               S46L
#                                                    whiB6  -75.0          -75_del_g
#                                                    yrbE2A  111.0             A111A
#                                                            160.0             L160L
#                                                    zwf1   -14.0              c-14t
#
#                                                                          REF
# UNIQUEID                                           GENE   GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE1     485.0         ctg  \
#                                                    PE14    106.0         gca
#                                                    PE16    96.0          gcg
#                                                    PE23    282.0         agt
#                                                            344.0         gcc
# ...                                                                      ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... vapC47  46.0          tcg
#                                                    whiB6  -75.0          NaN
#                                                    yrbE2A  111.0         gcc
#                                                            160.0         ctt
#                                                    zwf1   -14.0            c
#
#                                                                           ALT
# UNIQUEID                                           GENE   GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE1     485.0          ttg  \
#                                                    PE14    106.0          gcc
#                                                    PE16    96.0           gct
#                                                    PE23    282.0          agg
#                                                            344.0          acc
# ...                                                                       ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... vapC47  46.0           ttg
#                                                    whiB6  -75.0          None
#                                                    yrbE2A  111.0          gcg
#                                                            160.0          ctc
#                                                    zwf1   -14.0             t
#
#                                                                          NUCLEOTIDE_NUMBER
# UNIQUEID                                           GENE   GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE1     485.0                       NaN  \
#                                                    PE14    106.0                       NaN
#                                                    PE16    96.0                        NaN
#                                                    PE23    282.0                       NaN
#                                                            344.0                       NaN
# ...                                                                                    ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... vapC47  46.0                        NaN
#                                                    whiB6  -75.0                      -75.0
#                                                    yrbE2A  111.0                       NaN
#                                                            160.0                       NaN
#                                                    zwf1   -14.0                      -14.0
#
#                                                                          NUCLEOTIDE_INDEX
# UNIQUEID                                           GENE   GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE1     485.0                      NaN  \
#                                                    PE14    106.0                      NaN
#                                                    PE16    96.0                       NaN
#                                                    PE23    282.0                      NaN
#                                                            344.0                      NaN
# ...                                                                                   ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... vapC47  46.0                       NaN
#                                                    whiB6  -75.0                 4338596.0
#                                                    yrbE2A  111.0                      NaN
#                                                            160.0                      NaN
#                                                    zwf1   -14.0                 1243693.0
#
#                                                                          CODES_PROTEIN
# UNIQUEID                                           GENE   GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE1     485.0                  True  \
#                                                    PE14    106.0                  True
#                                                    PE16    96.0                   True
#                                                    PE23    282.0                  True
#                                                            344.0                  True
# ...                                                                                ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... vapC47  46.0                   True
#                                                    whiB6  -75.0                  False
#                                                    yrbE2A  111.0                  True
#                                                            160.0                  True
#                                                    zwf1   -14.0                  False
#
#                                                                          INDEL_LENGTH
# UNIQUEID                                           GENE   GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE1     485.0                  NaN  \
#                                                    PE14    106.0                  NaN
#                                                    PE16    96.0                   NaN
#                                                    PE23    282.0                  NaN
#                                                            344.0                  NaN
# ...                                                                               ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... vapC47  46.0                   NaN
#                                                    whiB6  -75.0                  -1.0
#                                                    yrbE2A  111.0                  NaN
#                                                            160.0                  NaN
#                                                    zwf1   -14.0                   NaN
#
#                                                                         INDEL_NUCLEOTIDES
# UNIQUEID                                           GENE   GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE1     485.0                     None  \
#                                                    PE14    106.0                     None
#                                                    PE16    96.0                      None
#                                                    PE23    282.0                     None
#                                                            344.0                     None
# ...                                                                                   ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... vapC47  46.0                      None
#                                                    whiB6  -75.0                         g
#                                                    yrbE2A  111.0                     None
#                                                            160.0                     None
#                                                    zwf1   -14.0                      None
#
#                                                                          AMINO_ACID_NUMBER
# UNIQUEID                                           GENE   GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE1     485.0                     485.0  \
#                                                    PE14    106.0                     106.0
#                                                    PE16    96.0                       96.0
#                                                    PE23    282.0                     282.0
#                                                            344.0                     344.0
# ...                                                                                    ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... vapC47  46.0                       46.0
#                                                    whiB6  -75.0                        NaN
#                                                    yrbE2A  111.0                     111.0
#                                                            160.0                     160.0
#                                                    zwf1   -14.0                        NaN
#
#                                                                         AMINO_ACID_SEQUENCE
# UNIQUEID                                           GENE   GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE1     485.0                          L  \
#                                                    PE14    106.0                          A
#                                                    PE16    96.0                           A
#                                                    PE23    282.0                          R
#                                                            344.0                          T
# ...                                                                                     ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... vapC47  46.0                           L
#                                                    whiB6  -75.0                        None
#                                                    yrbE2A  111.0                          A
#                                                            160.0                          L
#                                                    zwf1   -14.0                        None
#
#                                                                          NUMBER_NUCLEOTIDE_CHANGES
# UNIQUEID                                           GENE   GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE1     485.0                               1.0  \
#                                                    PE14    106.0                               1.0
#                                                    PE16    96.0                                1.0
#                                                    PE23    282.0                               1.0
#                                                            344.0                               1.0
# ...                                                                                            ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... vapC47  46.0                                1.0
#                                                    whiB6  -75.0                                NaN
#                                                    yrbE2A  111.0                               1.0
#                                                            160.0                               1.0
#                                                    zwf1   -14.0                                1.0
#
#                                                                          IS_NULL
# UNIQUEID                                           GENE   GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE1     485.0           False  \
#                                                    PE14    106.0           False
#                                                    PE16    96.0            False
#                                                    PE23    282.0           False
#                                                            344.0           False
# ...                                                                          ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... vapC47  46.0            False
#                                                    whiB6  -75.0            False
#                                                    yrbE2A  111.0           False
#                                                            160.0           False
#                                                    zwf1   -14.0            False
#
#                                                                          IS_MINOR
# UNIQUEID                                           GENE   GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE1     485.0            False  \
#                                                    PE14    106.0            False
#                                                    PE16    96.0             False
#                                                    PE23    282.0            False
#                                                            344.0            False
# ...                                                                           ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... vapC47  46.0             False
#                                                    whiB6  -75.0             False
#                                                    yrbE2A  111.0            False
#                                                            160.0            False
#                                                    zwf1   -14.0             False
#
#                                                                          MINOR_READS
# UNIQUEID                                           GENE   GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE1     485.0                 NaN  \
#                                                    PE14    106.0                 NaN
#                                                    PE16    96.0                  NaN
#                                                    PE23    282.0                 NaN
#                                                            344.0                 NaN
# ...                                                                              ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... vapC47  46.0                  NaN
#                                                    whiB6  -75.0                  NaN
#                                                    yrbE2A  111.0                 NaN
#                                                            160.0                 NaN
#                                                    zwf1   -14.0                  NaN
#
#                                                                         GENE_MUTATION_POSITION
# UNIQUEID                                           GENE   GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE1     485.0                     PE1_485.0  \
#                                                    PE14    106.0                    PE14_106.0
#                                                    PE16    96.0                      PE16_96.0
#                                                    PE23    282.0                    PE23_282.0
#                                                            344.0                    PE23_344.0
# ...                                                                                        ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... vapC47  46.0                    vapC47_46.0
#                                                    whiB6  -75.0                    whiB6_-75.0
#                                                    yrbE2A  111.0                  yrbE2A_111.0
#                                                            160.0                  yrbE2A_160.0
#                                                    zwf1   -14.0                     zwf1_-14.0
#
#                                                                          COVERAGE
# UNIQUEID                                           GENE   GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE1     485.0            155.0  \
#                                                    PE14    106.0             73.0
#                                                    PE16    96.0             111.0
#                                                    PE23    282.0            181.0
#                                                            344.0            128.0
# ...                                                                           ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... vapC47  46.0              42.0
#                                                    whiB6  -75.0              67.0
#                                                    yrbE2A  111.0             70.0
#                                                            160.0             68.0
#                                                    zwf1   -14.0              37.0
#
#                                                                          FRS
# UNIQUEID                                           GENE   GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE1     485.0         1.0  \
#                                                    PE14    106.0         1.0
#                                                    PE16    96.0          1.0
#                                                    PE23    282.0         1.0
#                                                            344.0         1.0
# ...                                                                      ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... vapC47  46.0          1.0
#                                                    whiB6  -75.0          1.0
#                                                    yrbE2A  111.0         1.0
#                                                            160.0         1.0
#                                                    zwf1   -14.0          1.0
#
#                                                                            GENE_MUTATION
# UNIQUEID                                           GENE   GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE1     485.0               PE1_L485L
#                                                    PE14    106.0              PE14_A106A
#                                                    PE16    96.0                PE16_A96A
#                                                    PE23    282.0              PE23_S282R
#                                                            344.0              PE23_A344T
# ...                                                                                  ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... vapC47  46.0              vapC47_S46L
#                                                    whiB6  -75.0          whiB6_-75_del_g
#                                                    yrbE2A  111.0            yrbE2A_A111A
#                                                            160.0            yrbE2A_L160L
#                                                    zwf1   -14.0               zwf1_c-14t
#
# [458995 rows x 19 columns]

# %% [markdown]
# While we are at it, we will also check the percentage of heterogeneous samples with the mutation S450L

# %%
S450L_check = copy.deepcopy(solo_rif_mutations)
S450L_check.reset_index(inplace=True)
S450L_samples = S450L_check[S450L_check.MINOR_MUTATION == 'S450L'].UNIQUEID
non_S450L_samples = S450L_check[S450L_check.MINOR_MUTATION != 'S450L'].UNIQUEID
print(f"There are {len(S450L_samples)} samples with the minor RAV rpoB_S450L and {len(non_S450L_samples)} samples with a different minor RAV in our heterogeneous samples.")
print(f"This means that {len(S450L_samples)/(len(S450L_samples) + len(non_S450L_samples)) * 100:.1f}% of heterogeneous samples show the RAV rpoB_S450L.")

cm_mutations_S450L = mutations[mutations.UNIQUEID.isin(S450L_samples) & mutations.GENE_MUTATION.isin(compensatory_mutations)]
cm_mutations_S450L
# Out:
# There are 150 samples with the minor RAV rpoB_S450L and 98 samples with a different minor RAV in our heterogeneous samples.
# This means that 60.5% of heterogeneous samples show the RAV rpoB_S450L.
#                                               UNIQUEID MINOR_MUTATION  GENE
# 28341              site.04.subj.00574.lab.706414.iso.1           P45S  rpoB  \
# 33256         site.08.subj.28TB-D06-009.lab.2849.iso.1         P1040A  rpoC
# 36265              site.04.subj.05164.lab.928554.iso.1          I491T  rpoC
# 41857       site.05.subj.LS-1669.lab.MA-01736-19.iso.1         P1040A  rpoC
# 43729     site.10.subj.YA00025832.lab.YA00025832.iso.1          L527V  rpoC
# ...                                                ...            ...   ...
# 628295     site.05.subj.LI2174109.lab.14893_2_18.iso.1         P1040A  rpoC
# 630447             site.04.subj.06221.lab.943340.iso.1          D485N  rpoC
# 638543  site.08.subj.BTN_P299_17.lab.BTN_P299_17.iso.1          L516P  rpoC
# 639516      site.05.subj.LR-2285.lab.FN-00492-18.iso.1          G433S  rpoC
# 656934             site.04.subj.03267.lab.824801.iso.1            NaN  rpoC
#
#        MUTATION  REF  ALT  NUCLEOTIDE_NUMBER  NUCLEOTIDE_INDEX  GENE_POSITION
# 28341      P45Z  ccg  tcg                NaN               NaN           45.0  \
# 33256    P1040Z  ccg  gcg                NaN               NaN         1040.0
# 36265     I491Z  atc  acc                NaN               NaN          491.0
# 41857    P1040Z  ccg  gcg                NaN               NaN         1040.0
# 43729     L527Z  ttg  gtg                NaN               NaN          527.0
# ...         ...  ...  ...                ...               ...            ...
# 628295   P1040Z  ccg  gcg                NaN               NaN         1040.0
# 630447    D485Z  gat  aat                NaN               NaN          485.0
# 638543    L516Z  ctg  ccg                NaN               NaN          516.0
# 639516    G433Z  ggc  agc                NaN               NaN          433.0
# 656934    N698K  aac  aaa                NaN               NaN          698.0
#
#         CODES_PROTEIN  ...  AMINO_ACID_NUMBER AMINO_ACID_SEQUENCE
# 28341            True  ...               45.0                   S  \
# 33256            True  ...             1040.0                   A
# 36265            True  ...              491.0                   T
# 41857            True  ...             1040.0                   A
# 43729            True  ...              527.0                   V
# ...               ...  ...                ...                 ...
# 628295           True  ...             1040.0                   A
# 630447           True  ...              485.0                   N
# 638543           True  ...              516.0                   P
# 639516           True  ...              433.0                   S
# 656934           True  ...              698.0                   K
#
#         NUMBER_NUCLEOTIDE_CHANGES IS_NULL  IS_MINOR  MINOR_READS
# 28341                         1.0   False      True         21.0  \
# 33256                         1.0   False      True          5.0
# 36265                         1.0   False      True         12.0
# 41857                         1.0   False      True          3.0
# 43729                         1.0   False      True         31.0
# ...                           ...     ...       ...          ...
# 628295                        1.0   False      True         35.0
# 630447                        1.0   False      True         64.0
# 638543                        1.0   False      True         66.0
# 639516                        1.0   False      True         91.0
# 656934                        1.0   False     False          NaN
#
#         GENE_MUTATION_POSITION  COVERAGE       FRS  GENE_MUTATION
# 28341                rpoB_45.0      57.0  0.368421      rpoB_P45S
# 33256              rpoC_1040.0      19.0  0.263158    rpoC_P1040A
# 36265               rpoC_491.0     103.0  0.116505     rpoC_I491T
# 41857              rpoC_1040.0      15.0  0.200000    rpoC_P1040A
# 43729               rpoC_527.0     151.0  0.205298     rpoC_L527V
# ...                        ...       ...       ...            ...
# 628295             rpoC_1040.0      46.0  0.760870    rpoC_P1040A
# 630447              rpoC_485.0      83.0  0.771084     rpoC_D485N
# 638543              rpoC_516.0     187.0  0.352941     rpoC_L516P
# 639516              rpoC_433.0     104.0  0.875000     rpoC_G433S
# 656934              rpoC_698.0      98.0  1.000000     rpoC_N698K
#
# [96 rows x 22 columns]

# %% [markdown]
# We now want to know if CMs mostly occur in these S450L samples

# %%
cm_mutations_S450L = mutations[mutations.UNIQUEID.isin(S450L_samples) & mutations.GENE_MUTATION.isin(compensatory_mutations)]
print(f"Within the {len(S450L_samples)} samples with a minor RAV of rpoB_S450L, {len(cm_mutations_S450L.UNIQUEID.unique())} ({cm_mutations_S450L.UNIQUEID.unique().size/len(S450L_samples)*100:.1f}%) have at least one compensatory mutation in the RNAP, which is higher than the overall level of compensation in homogeneous samples.")
# Out:
# Within the 150 samples with a minor RAV of rpoB_S450L, 94 (62.7%) have at least one compensatory mutation in the RNAP, which is higher than the overall level of compensation in homogeneous samples.

# %%
cm_mutations_other = mutations[mutations.UNIQUEID.isin(non_S450L_samples) & mutations.GENE_MUTATION.isin(compensatory_mutations)]
cm_mutations_other
print(f"Within the {len(non_S450L_samples)} samples with a minor RAV other than rpoB_S450L, {len(cm_mutations_other.UNIQUEID.unique())} ({cm_mutations_other.UNIQUEID.unique().size/len(non_S450L_samples)*100:.1f}%) have at least one compensatory mutation in the RNAP.")
# Out:
# Within the 98 samples with a minor RAV other than rpoB_S450L, 4 (4.1%) have at least one compensatory mutation in the RNAP.

# %% [markdown]
# To compare this to homogeneous samples, we also check the rate of the RAV S450L in those samples

# %%
mutations_all = pd.read_parquet('data/cryptic_3/RNAP_MUTATIONS.parquet', engine='pyarrow')

mutations_all['GENE_MUTATION'] = mutations_all['GENE'] + '_' + mutations_all['MUTATION']

res_major_uniqueids = samples[(~samples['HAS_MINOR_RAV']) & (samples['HAS_MAJOR_RAV'])].index

effects_subset_all = effects[effects.UNIQUEID.isin(res_major_uniqueids)]
summary_rif_all = effects_subset_all[['UNIQUEID', 'MUTATION']].groupby('UNIQUEID').count()

solo_rif_all = summary_rif_all[summary_rif_all.MUTATION==1]
solo_rif_effects_all = effects[effects.UNIQUEID.isin(solo_rif_all.index)]
solo_rif_effects_all['MUTATION'] = solo_rif_effects_all['MUTATION'].str.replace(r':.*', '', regex=True)
solo_rif_effects_all.set_index(['UNIQUEID','GENE_MUTATION'], inplace=True)

mutations_all.set_index(['UNIQUEID','GENE_MUTATION'], inplace=True)

solo_rif_mutations_all = mutations_all[mutations_all.index.isin(solo_rif_effects_all.index)]
solo_rif_mutations_all.reset_index(inplace=True)
solo_rif_mutations_all.set_index(['UNIQUEID','GENE','GENE_POSITION'], inplace=True)

solo_rif_mutations.GENE_MUTATION.value_counts()[0]/sum(solo_rif_mutations_all.GENE_MUTATION.value_counts())
print(f"{solo_rif_mutations_all.GENE_MUTATION.value_counts()[0]/sum(solo_rif_mutations_all.GENE_MUTATION.value_counts())*100:.1f}% of the major RAVs in the homogeneous samples are rpoB S450L.")
# Out:
# 68.6% of the major RAVs in the homogeneous samples are rpoB S450L.
# /var/folders/_3/8y_dwngx2614_y_52fzh1c4w0000gn/T/ipykernel_30567/1465157930.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   solo_rif_effects_all['MUTATION'] = solo_rif_effects_all['MUTATION'].str.replace(r':.*', '', regex=True)

# %% [markdown]
# To get back to the evaluation of the number of minor mutations in heterogeneous samples, we count the number of minor mutations in each of the 248 samples with one RIF RAV <0.90 FRS

# %%
#here we need to ignore any null calls, any non minor calls and we set a threshold based on `COV` 
solo_other_variants = solo_other_mutations[(solo_other_mutations.IS_MINOR) & (~solo_other_mutations.IS_NULL) & (solo_other_mutations.COVERAGE>5) & (solo_other_mutations.FRS<0.9)]
solo_other_variants
# Out:
#                                                                            MINOR_MUTATION
# UNIQUEID                                           GENE      GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE_PGRS10 362.0                  I362L  \
#                                                              364.0                  G364G
#                                                              365.0                  T365L
#                                                              366.0                  G366G
#                                                              368.0                  V368Q
# ...                                                                                   ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... dop       7.0                      P7R
#                                                    esxL      8.0                      G8G
#                                                              13.0                    H13H
#                                                              37.0                    T37A
#                                                              39.0                    S39G
#
#                                                                            MUTATION
# UNIQUEID                                           GENE      GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE_PGRS10 362.0            I362Z  \
#                                                              364.0            G364Z
#                                                              365.0            T365Z
#                                                              366.0            G366Z
#                                                              368.0            V368Z
# ...                                                                             ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... dop       7.0                P7Z
#                                                    esxL      8.0                G8Z
#                                                              13.0              H13Z
#                                                              37.0              T37Z
#                                                              39.0              S39Z
#
#                                                                             REF
# UNIQUEID                                           GENE      GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE_PGRS10 362.0          atc  \
#                                                              364.0          ggt
#                                                              365.0          acc
#                                                              366.0          ggg
#                                                              368.0          gtg
# ...                                                                         ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... dop       7.0            cct
#                                                    esxL      8.0            ggg
#                                                              13.0           cac
#                                                              37.0           acc
#                                                              39.0           agt
#
#                                                                             ALT
# UNIQUEID                                           GENE      GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE_PGRS10 362.0          ctc  \
#                                                              364.0          ggc
#                                                              365.0          ctc
#                                                              366.0          ggc
#                                                              368.0          cag
# ...                                                                         ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... dop       7.0            cgt
#                                                    esxL      8.0            ggt
#                                                              13.0           cat
#                                                              37.0           gcc
#                                                              39.0           ggt
#
#                                                                             NUCLEOTIDE_NUMBER
# UNIQUEID                                           GENE      GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE_PGRS10 362.0                        NaN  \
#                                                              364.0                        NaN
#                                                              365.0                        NaN
#                                                              366.0                        NaN
#                                                              368.0                        NaN
# ...                                                                                       ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... dop       7.0                          NaN
#                                                    esxL      8.0                          NaN
#                                                              13.0                         NaN
#                                                              37.0                         NaN
#                                                              39.0                         NaN
#
#                                                                             NUCLEOTIDE_INDEX
# UNIQUEID                                           GENE      GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE_PGRS10 362.0                       NaN  \
#                                                              364.0                       NaN
#                                                              365.0                       NaN
#                                                              366.0                       NaN
#                                                              368.0                       NaN
# ...                                                                                      ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... dop       7.0                         NaN
#                                                    esxL      8.0                         NaN
#                                                              13.0                        NaN
#                                                              37.0                        NaN
#                                                              39.0                        NaN
#
#                                                                             CODES_PROTEIN
# UNIQUEID                                           GENE      GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE_PGRS10 362.0                   True  \
#                                                              364.0                   True
#                                                              365.0                   True
#                                                              366.0                   True
#                                                              368.0                   True
# ...                                                                                   ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... dop       7.0                     True
#                                                    esxL      8.0                     True
#                                                              13.0                    True
#                                                              37.0                    True
#                                                              39.0                    True
#
#                                                                             INDEL_LENGTH
# UNIQUEID                                           GENE      GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE_PGRS10 362.0                   NaN  \
#                                                              364.0                   NaN
#                                                              365.0                   NaN
#                                                              366.0                   NaN
#                                                              368.0                   NaN
# ...                                                                                  ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... dop       7.0                     NaN
#                                                    esxL      8.0                     NaN
#                                                              13.0                    NaN
#                                                              37.0                    NaN
#                                                              39.0                    NaN
#
#                                                                            INDEL_NUCLEOTIDES
# UNIQUEID                                           GENE      GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE_PGRS10 362.0                      None  \
#                                                              364.0                      None
#                                                              365.0                      None
#                                                              366.0                      None
#                                                              368.0                      None
# ...                                                                                      ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... dop       7.0                        None
#                                                    esxL      8.0                        None
#                                                              13.0                       None
#                                                              37.0                       None
#                                                              39.0                       None
#
#                                                                             AMINO_ACID_NUMBER
# UNIQUEID                                           GENE      GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE_PGRS10 362.0                      362.0  \
#                                                              364.0                      364.0
#                                                              365.0                      365.0
#                                                              366.0                      366.0
#                                                              368.0                      368.0
# ...                                                                                       ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... dop       7.0                          7.0
#                                                    esxL      8.0                          8.0
#                                                              13.0                        13.0
#                                                              37.0                        37.0
#                                                              39.0                        39.0
#
#                                                                            AMINO_ACID_SEQUENCE
# UNIQUEID                                           GENE      GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE_PGRS10 362.0                           L  \
#                                                              364.0                           G
#                                                              365.0                           L
#                                                              366.0                           G
#                                                              368.0                           Q
# ...                                                                                        ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... dop       7.0                             R
#                                                    esxL      8.0                             G
#                                                              13.0                            H
#                                                              37.0                            A
#                                                              39.0                            G
#
#                                                                             NUMBER_NUCLEOTIDE_CHANGES
# UNIQUEID                                           GENE      GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE_PGRS10 362.0                                1.0  \
#                                                              364.0                                1.0
#                                                              365.0                                2.0
#                                                              366.0                                1.0
#                                                              368.0                                2.0
# ...                                                                                               ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... dop       7.0                                  1.0
#                                                    esxL      8.0                                  1.0
#                                                              13.0                                 1.0
#                                                              37.0                                 1.0
#                                                              39.0                                 1.0
#
#                                                                             IS_NULL
# UNIQUEID                                           GENE      GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE_PGRS10 362.0            False  \
#                                                              364.0            False
#                                                              365.0            False
#                                                              366.0            False
#                                                              368.0            False
# ...                                                                             ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... dop       7.0              False
#                                                    esxL      8.0              False
#                                                              13.0             False
#                                                              37.0             False
#                                                              39.0             False
#
#                                                                             IS_MINOR
# UNIQUEID                                           GENE      GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE_PGRS10 362.0              True  \
#                                                              364.0              True
#                                                              365.0              True
#                                                              366.0              True
#                                                              368.0              True
# ...                                                                              ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... dop       7.0                True
#                                                    esxL      8.0                True
#                                                              13.0               True
#                                                              37.0               True
#                                                              39.0               True
#
#                                                                             MINOR_READS
# UNIQUEID                                           GENE      GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE_PGRS10 362.0                  6.0  \
#                                                              364.0                  5.0
#                                                              365.0                  5.0
#                                                              366.0                  5.0
#                                                              368.0                  6.0
# ...                                                                                 ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... dop       7.0                    4.0
#                                                    esxL      8.0                   64.0
#                                                              13.0                  58.0
#                                                              37.0                  26.0
#                                                              39.0                  18.0
#
#                                                                            GENE_MUTATION_POSITION
# UNIQUEID                                           GENE      GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE_PGRS10 362.0                PE_PGRS10_362.0  \
#                                                              364.0                PE_PGRS10_364.0
#                                                              365.0                PE_PGRS10_365.0
#                                                              366.0                PE_PGRS10_366.0
#                                                              368.0                PE_PGRS10_368.0
# ...                                                                                           ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... dop       7.0                          dop_7.0
#                                                    esxL      8.0                         esxL_8.0
#                                                              13.0                       esxL_13.0
#                                                              37.0                       esxL_37.0
#                                                              39.0                       esxL_39.0
#
#                                                                             COVERAGE
# UNIQUEID                                           GENE      GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE_PGRS10 362.0              58.0  \
#                                                              364.0              53.0
#                                                              365.0              55.0
#                                                              366.0              56.0
#                                                              368.0              67.0
# ...                                                                              ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... dop       7.0                76.0
#                                                    esxL      8.0               118.0
#                                                              13.0              107.0
#                                                              37.0               74.0
#                                                              39.0               63.0
#
#                                                                                  FRS
# UNIQUEID                                           GENE      GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE_PGRS10 362.0          0.103448  \
#                                                              364.0          0.094340
#                                                              365.0          0.090909
#                                                              366.0          0.089286
#                                                              368.0          0.089552
# ...                                                                              ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... dop       7.0            0.052632
#                                                    esxL      8.0            0.542373
#                                                              13.0           0.542056
#                                                              37.0           0.351351
#                                                              39.0           0.285714
#
#                                                                               GENE_MUTATION
# UNIQUEID                                           GENE      GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       PE_PGRS10 362.0          PE_PGRS10_I362L
#                                                              364.0          PE_PGRS10_G364G
#                                                              365.0          PE_PGRS10_T365L
#                                                              366.0          PE_PGRS10_G366G
#                                                              368.0          PE_PGRS10_V368Q
# ...                                                                                     ...
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... dop       7.0                    dop_P7R
#                                                    esxL      8.0                   esxL_G8G
#                                                              13.0                 esxL_H13H
#                                                              37.0                 esxL_T37A
#                                                              39.0                 esxL_S39G
#
# [189211 rows x 19 columns]

# %%
solo_other_variants.reset_index(inplace=True)
solo_other_variants_count = solo_other_variants[['UNIQUEID','GENE_POSITION']].groupby('UNIQUEID').count()
solo_other_variants_count.rename(columns={'GENE_POSITION':'MINOR_COUNT'}, inplace=True)
solo_other_variants_count
# Out:
#                                                     MINOR_COUNT
# UNIQUEID
# site.00.subj.1473471.lab.H140800280.iso.1                    86
# site.00.subj.1473471.lab.H142100097.iso.1                    80
# site.00.subj.ES_FE21.lab.FE21.iso.1                          82
# site.00.subj.NETHERLANDS_NLA000301359.lab.NLA00...           70
# site.01.subj.DR0182.lab.DR0182.iso.1                       1124
# ...                                                         ...
# site.ENA.subj.SAMN03648068.lab.1.iso.1                      185
# site.ENA.subj.SAMN03648752.lab.1.iso.1                      103
# site.ENA.subj.SAMN03648842.lab.1.iso.1                       43
# site.ENA.subj.SAMN07236317.lab.1.iso.1                       58
# site.ENA.subj.SAMN07978245.lab.1.iso.1                      866
#
# [248 rows x 1 columns]

# %% [markdown]
# Now we join the table containing the count of minor mutations per sample to a table reporting the RIF mutations in the 248 samples

# %%
solo_rif_variants = solo_mutations[solo_mutations.index.isin(solo_rif_mutations.index)]
solo_rif_variants

variant_count_all = solo_rif_variants.join(solo_other_variants_count)
variant_count_all.MINOR_COUNT.fillna(0, inplace=True)
variant_count_all
# Out:
#                                                                       MINOR_MUTATION
# UNIQUEID                                           GENE GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       rpoB 430.0                  L430P  \
# site.05.subj.LR-2502.lab.FN-01440-17.iso.1         rpoB 450.0                  S450L
# site.02.subj.0431.lab.235049-14.iso.1              rpoB 430.0                  L430P
# site.ENA.subj.SAMEA1403636.lab.1.iso.1             rpoB 450.0                  S450L
# site.ENA.subj.SAMN07978245.lab.1.iso.1             rpoB 450.0                  S450L
# ...                                                                              ...
# site.04.subj.03297.lab.824687.iso.1                rpoB 430.0                  L430P
# site.10.subj.MG03902304.lab.MG03902304.iso.1       rpoB 430.0                  L430P
# site.04.subj.03267.lab.824801.iso.1                rpoB 450.0                  S450L
# site.04.subj.05976.lab.916301.iso.1                rpoB 450.0                  S450L
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... rpoB 445.0                  H445D
#
#                                                                       MUTATION
# UNIQUEID                                           GENE GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       rpoB 430.0            L430Z  \
# site.05.subj.LR-2502.lab.FN-01440-17.iso.1         rpoB 450.0            S450Z
# site.02.subj.0431.lab.235049-14.iso.1              rpoB 430.0            L430Z
# site.ENA.subj.SAMEA1403636.lab.1.iso.1             rpoB 450.0            S450Z
# site.ENA.subj.SAMN07978245.lab.1.iso.1             rpoB 450.0            S450Z
# ...                                                                        ...
# site.04.subj.03297.lab.824687.iso.1                rpoB 430.0            L430Z
# site.10.subj.MG03902304.lab.MG03902304.iso.1       rpoB 430.0            L430Z
# site.04.subj.03267.lab.824801.iso.1                rpoB 450.0            S450Z
# site.04.subj.05976.lab.916301.iso.1                rpoB 450.0            S450Z
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... rpoB 445.0            H445Z
#
#                                                                        REF
# UNIQUEID                                           GENE GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       rpoB 430.0          ctg  \
# site.05.subj.LR-2502.lab.FN-01440-17.iso.1         rpoB 450.0          tcg
# site.02.subj.0431.lab.235049-14.iso.1              rpoB 430.0          ctg
# site.ENA.subj.SAMEA1403636.lab.1.iso.1             rpoB 450.0          tcg
# site.ENA.subj.SAMN07978245.lab.1.iso.1             rpoB 450.0          tcg
# ...                                                                    ...
# site.04.subj.03297.lab.824687.iso.1                rpoB 430.0          ctg
# site.10.subj.MG03902304.lab.MG03902304.iso.1       rpoB 430.0          ctg
# site.04.subj.03267.lab.824801.iso.1                rpoB 450.0          tcg
# site.04.subj.05976.lab.916301.iso.1                rpoB 450.0          tcg
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... rpoB 445.0          cac
#
#                                                                        ALT
# UNIQUEID                                           GENE GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       rpoB 430.0          ccg  \
# site.05.subj.LR-2502.lab.FN-01440-17.iso.1         rpoB 450.0          ttg
# site.02.subj.0431.lab.235049-14.iso.1              rpoB 430.0          ccg
# site.ENA.subj.SAMEA1403636.lab.1.iso.1             rpoB 450.0          ttg
# site.ENA.subj.SAMN07978245.lab.1.iso.1             rpoB 450.0          ttg
# ...                                                                    ...
# site.04.subj.03297.lab.824687.iso.1                rpoB 430.0          ccg
# site.10.subj.MG03902304.lab.MG03902304.iso.1       rpoB 430.0          ccg
# site.04.subj.03267.lab.824801.iso.1                rpoB 450.0          ttg
# site.04.subj.05976.lab.916301.iso.1                rpoB 450.0          ttg
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... rpoB 445.0          gac
#
#                                                                        NUCLEOTIDE_NUMBER
# UNIQUEID                                           GENE GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       rpoB 430.0                        NaN  \
# site.05.subj.LR-2502.lab.FN-01440-17.iso.1         rpoB 450.0                        NaN
# site.02.subj.0431.lab.235049-14.iso.1              rpoB 430.0                        NaN
# site.ENA.subj.SAMEA1403636.lab.1.iso.1             rpoB 450.0                        NaN
# site.ENA.subj.SAMN07978245.lab.1.iso.1             rpoB 450.0                        NaN
# ...                                                                                  ...
# site.04.subj.03297.lab.824687.iso.1                rpoB 430.0                        NaN
# site.10.subj.MG03902304.lab.MG03902304.iso.1       rpoB 430.0                        NaN
# site.04.subj.03267.lab.824801.iso.1                rpoB 450.0                        NaN
# site.04.subj.05976.lab.916301.iso.1                rpoB 450.0                        NaN
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... rpoB 445.0                        NaN
#
#                                                                        NUCLEOTIDE_INDEX
# UNIQUEID                                           GENE GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       rpoB 430.0                       NaN  \
# site.05.subj.LR-2502.lab.FN-01440-17.iso.1         rpoB 450.0                       NaN
# site.02.subj.0431.lab.235049-14.iso.1              rpoB 430.0                       NaN
# site.ENA.subj.SAMEA1403636.lab.1.iso.1             rpoB 450.0                       NaN
# site.ENA.subj.SAMN07978245.lab.1.iso.1             rpoB 450.0                       NaN
# ...                                                                                 ...
# site.04.subj.03297.lab.824687.iso.1                rpoB 430.0                       NaN
# site.10.subj.MG03902304.lab.MG03902304.iso.1       rpoB 430.0                       NaN
# site.04.subj.03267.lab.824801.iso.1                rpoB 450.0                       NaN
# site.04.subj.05976.lab.916301.iso.1                rpoB 450.0                       NaN
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... rpoB 445.0                       NaN
#
#                                                                        CODES_PROTEIN
# UNIQUEID                                           GENE GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       rpoB 430.0                   True  \
# site.05.subj.LR-2502.lab.FN-01440-17.iso.1         rpoB 450.0                   True
# site.02.subj.0431.lab.235049-14.iso.1              rpoB 430.0                   True
# site.ENA.subj.SAMEA1403636.lab.1.iso.1             rpoB 450.0                   True
# site.ENA.subj.SAMN07978245.lab.1.iso.1             rpoB 450.0                   True
# ...                                                                              ...
# site.04.subj.03297.lab.824687.iso.1                rpoB 430.0                   True
# site.10.subj.MG03902304.lab.MG03902304.iso.1       rpoB 430.0                   True
# site.04.subj.03267.lab.824801.iso.1                rpoB 450.0                   True
# site.04.subj.05976.lab.916301.iso.1                rpoB 450.0                   True
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... rpoB 445.0                   True
#
#                                                                        INDEL_LENGTH
# UNIQUEID                                           GENE GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       rpoB 430.0                   NaN  \
# site.05.subj.LR-2502.lab.FN-01440-17.iso.1         rpoB 450.0                   NaN
# site.02.subj.0431.lab.235049-14.iso.1              rpoB 430.0                   NaN
# site.ENA.subj.SAMEA1403636.lab.1.iso.1             rpoB 450.0                   NaN
# site.ENA.subj.SAMN07978245.lab.1.iso.1             rpoB 450.0                   NaN
# ...                                                                             ...
# site.04.subj.03297.lab.824687.iso.1                rpoB 430.0                   NaN
# site.10.subj.MG03902304.lab.MG03902304.iso.1       rpoB 430.0                   NaN
# site.04.subj.03267.lab.824801.iso.1                rpoB 450.0                   NaN
# site.04.subj.05976.lab.916301.iso.1                rpoB 450.0                   NaN
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... rpoB 445.0                   NaN
#
#                                                                       INDEL_NUCLEOTIDES
# UNIQUEID                                           GENE GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       rpoB 430.0                      None  \
# site.05.subj.LR-2502.lab.FN-01440-17.iso.1         rpoB 450.0                      None
# site.02.subj.0431.lab.235049-14.iso.1              rpoB 430.0                      None
# site.ENA.subj.SAMEA1403636.lab.1.iso.1             rpoB 450.0                      None
# site.ENA.subj.SAMN07978245.lab.1.iso.1             rpoB 450.0                      None
# ...                                                                                 ...
# site.04.subj.03297.lab.824687.iso.1                rpoB 430.0                      None
# site.10.subj.MG03902304.lab.MG03902304.iso.1       rpoB 430.0                      None
# site.04.subj.03267.lab.824801.iso.1                rpoB 450.0                      None
# site.04.subj.05976.lab.916301.iso.1                rpoB 450.0                      None
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... rpoB 445.0                      None
#
#                                                                        AMINO_ACID_NUMBER
# UNIQUEID                                           GENE GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       rpoB 430.0                      430.0  \
# site.05.subj.LR-2502.lab.FN-01440-17.iso.1         rpoB 450.0                      450.0
# site.02.subj.0431.lab.235049-14.iso.1              rpoB 430.0                      430.0
# site.ENA.subj.SAMEA1403636.lab.1.iso.1             rpoB 450.0                      450.0
# site.ENA.subj.SAMN07978245.lab.1.iso.1             rpoB 450.0                      450.0
# ...                                                                                  ...
# site.04.subj.03297.lab.824687.iso.1                rpoB 430.0                      430.0
# site.10.subj.MG03902304.lab.MG03902304.iso.1       rpoB 430.0                      430.0
# site.04.subj.03267.lab.824801.iso.1                rpoB 450.0                      450.0
# site.04.subj.05976.lab.916301.iso.1                rpoB 450.0                      450.0
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... rpoB 445.0                      445.0
#
#                                                                       AMINO_ACID_SEQUENCE
# UNIQUEID                                           GENE GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       rpoB 430.0                           P  \
# site.05.subj.LR-2502.lab.FN-01440-17.iso.1         rpoB 450.0                           L
# site.02.subj.0431.lab.235049-14.iso.1              rpoB 430.0                           P
# site.ENA.subj.SAMEA1403636.lab.1.iso.1             rpoB 450.0                           L
# site.ENA.subj.SAMN07978245.lab.1.iso.1             rpoB 450.0                           L
# ...                                                                                   ...
# site.04.subj.03297.lab.824687.iso.1                rpoB 430.0                           P
# site.10.subj.MG03902304.lab.MG03902304.iso.1       rpoB 430.0                           P
# site.04.subj.03267.lab.824801.iso.1                rpoB 450.0                           L
# site.04.subj.05976.lab.916301.iso.1                rpoB 450.0                           L
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... rpoB 445.0                           D
#
#                                                                        NUMBER_NUCLEOTIDE_CHANGES
# UNIQUEID                                           GENE GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       rpoB 430.0                                1.0  \
# site.05.subj.LR-2502.lab.FN-01440-17.iso.1         rpoB 450.0                                1.0
# site.02.subj.0431.lab.235049-14.iso.1              rpoB 430.0                                1.0
# site.ENA.subj.SAMEA1403636.lab.1.iso.1             rpoB 450.0                                1.0
# site.ENA.subj.SAMN07978245.lab.1.iso.1             rpoB 450.0                                1.0
# ...                                                                                          ...
# site.04.subj.03297.lab.824687.iso.1                rpoB 430.0                                1.0
# site.10.subj.MG03902304.lab.MG03902304.iso.1       rpoB 430.0                                1.0
# site.04.subj.03267.lab.824801.iso.1                rpoB 450.0                                1.0
# site.04.subj.05976.lab.916301.iso.1                rpoB 450.0                                1.0
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... rpoB 445.0                                1.0
#
#                                                                        IS_NULL
# UNIQUEID                                           GENE GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       rpoB 430.0            False  \
# site.05.subj.LR-2502.lab.FN-01440-17.iso.1         rpoB 450.0            False
# site.02.subj.0431.lab.235049-14.iso.1              rpoB 430.0            False
# site.ENA.subj.SAMEA1403636.lab.1.iso.1             rpoB 450.0            False
# site.ENA.subj.SAMN07978245.lab.1.iso.1             rpoB 450.0            False
# ...                                                                        ...
# site.04.subj.03297.lab.824687.iso.1                rpoB 430.0            False
# site.10.subj.MG03902304.lab.MG03902304.iso.1       rpoB 430.0            False
# site.04.subj.03267.lab.824801.iso.1                rpoB 450.0            False
# site.04.subj.05976.lab.916301.iso.1                rpoB 450.0            False
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... rpoB 445.0            False
#
#                                                                        IS_MINOR
# UNIQUEID                                           GENE GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       rpoB 430.0              True  \
# site.05.subj.LR-2502.lab.FN-01440-17.iso.1         rpoB 450.0              True
# site.02.subj.0431.lab.235049-14.iso.1              rpoB 430.0              True
# site.ENA.subj.SAMEA1403636.lab.1.iso.1             rpoB 450.0              True
# site.ENA.subj.SAMN07978245.lab.1.iso.1             rpoB 450.0              True
# ...                                                                         ...
# site.04.subj.03297.lab.824687.iso.1                rpoB 430.0              True
# site.10.subj.MG03902304.lab.MG03902304.iso.1       rpoB 430.0              True
# site.04.subj.03267.lab.824801.iso.1                rpoB 450.0              True
# site.04.subj.05976.lab.916301.iso.1                rpoB 450.0              True
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... rpoB 445.0              True
#
#                                                                        MINOR_READS
# UNIQUEID                                           GENE GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       rpoB 430.0                 18.0  \
# site.05.subj.LR-2502.lab.FN-01440-17.iso.1         rpoB 450.0                 30.0
# site.02.subj.0431.lab.235049-14.iso.1              rpoB 430.0                 10.0
# site.ENA.subj.SAMEA1403636.lab.1.iso.1             rpoB 450.0                 40.0
# site.ENA.subj.SAMN07978245.lab.1.iso.1             rpoB 450.0                  4.0
# ...                                                                            ...
# site.04.subj.03297.lab.824687.iso.1                rpoB 430.0                  5.0
# site.10.subj.MG03902304.lab.MG03902304.iso.1       rpoB 430.0                 51.0
# site.04.subj.03267.lab.824801.iso.1                rpoB 450.0                 43.0
# site.04.subj.05976.lab.916301.iso.1                rpoB 450.0                  3.0
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... rpoB 445.0                 19.0
#
#                                                                       GENE_MUTATION_POSITION
# UNIQUEID                                           GENE GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       rpoB 430.0                     rpoB_430.0  \
# site.05.subj.LR-2502.lab.FN-01440-17.iso.1         rpoB 450.0                     rpoB_450.0
# site.02.subj.0431.lab.235049-14.iso.1              rpoB 430.0                     rpoB_430.0
# site.ENA.subj.SAMEA1403636.lab.1.iso.1             rpoB 450.0                     rpoB_450.0
# site.ENA.subj.SAMN07978245.lab.1.iso.1             rpoB 450.0                     rpoB_450.0
# ...                                                                                      ...
# site.04.subj.03297.lab.824687.iso.1                rpoB 430.0                     rpoB_430.0
# site.10.subj.MG03902304.lab.MG03902304.iso.1       rpoB 430.0                     rpoB_430.0
# site.04.subj.03267.lab.824801.iso.1                rpoB 450.0                     rpoB_450.0
# site.04.subj.05976.lab.916301.iso.1                rpoB 450.0                     rpoB_450.0
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... rpoB 445.0                     rpoB_445.0
#
#                                                                        COVERAGE
# UNIQUEID                                           GENE GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       rpoB 430.0              50.0  \
# site.05.subj.LR-2502.lab.FN-01440-17.iso.1         rpoB 450.0              47.0
# site.02.subj.0431.lab.235049-14.iso.1              rpoB 430.0             117.0
# site.ENA.subj.SAMEA1403636.lab.1.iso.1             rpoB 450.0              49.0
# site.ENA.subj.SAMN07978245.lab.1.iso.1             rpoB 450.0               5.0
# ...                                                                         ...
# site.04.subj.03297.lab.824687.iso.1                rpoB 430.0              18.0
# site.10.subj.MG03902304.lab.MG03902304.iso.1       rpoB 430.0              57.0
# site.04.subj.03267.lab.824801.iso.1                rpoB 450.0              48.0
# site.04.subj.05976.lab.916301.iso.1                rpoB 450.0              20.0
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... rpoB 445.0              30.0
#
#                                                                             FRS
# UNIQUEID                                           GENE GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       rpoB 430.0          0.360000  \
# site.05.subj.LR-2502.lab.FN-01440-17.iso.1         rpoB 450.0          0.638298
# site.02.subj.0431.lab.235049-14.iso.1              rpoB 430.0          0.085470
# site.ENA.subj.SAMEA1403636.lab.1.iso.1             rpoB 450.0          0.816327
# site.ENA.subj.SAMN07978245.lab.1.iso.1             rpoB 450.0          0.800000
# ...                                                                         ...
# site.04.subj.03297.lab.824687.iso.1                rpoB 430.0          0.277778
# site.10.subj.MG03902304.lab.MG03902304.iso.1       rpoB 430.0          0.894737
# site.04.subj.03267.lab.824801.iso.1                rpoB 450.0          0.895833
# site.04.subj.05976.lab.916301.iso.1                rpoB 450.0          0.150000
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... rpoB 445.0          0.633333
#
#                                                                       GENE_MUTATION
# UNIQUEID                                           GENE GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       rpoB 430.0            rpoB_L430P  \
# site.05.subj.LR-2502.lab.FN-01440-17.iso.1         rpoB 450.0            rpoB_S450L
# site.02.subj.0431.lab.235049-14.iso.1              rpoB 430.0            rpoB_L430P
# site.ENA.subj.SAMEA1403636.lab.1.iso.1             rpoB 450.0            rpoB_S450L
# site.ENA.subj.SAMN07978245.lab.1.iso.1             rpoB 450.0            rpoB_S450L
# ...                                                                             ...
# site.04.subj.03297.lab.824687.iso.1                rpoB 430.0            rpoB_L430P
# site.10.subj.MG03902304.lab.MG03902304.iso.1       rpoB 430.0            rpoB_L430P
# site.04.subj.03267.lab.824801.iso.1                rpoB 450.0            rpoB_S450L
# site.04.subj.05976.lab.916301.iso.1                rpoB 450.0            rpoB_S450L
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... rpoB 445.0            rpoB_H445D
#
#                                                                        MINOR_COUNT
# UNIQUEID                                           GENE GENE_POSITION
# site.10.subj.NG00204540.lab.NG00204540.iso.1       rpoB 430.0                  127
# site.05.subj.LR-2502.lab.FN-01440-17.iso.1         rpoB 450.0                  967
# site.02.subj.0431.lab.235049-14.iso.1              rpoB 430.0                  169
# site.ENA.subj.SAMEA1403636.lab.1.iso.1             rpoB 450.0                  876
# site.ENA.subj.SAMN07978245.lab.1.iso.1             rpoB 450.0                  866
# ...                                                                            ...
# site.04.subj.03297.lab.824687.iso.1                rpoB 430.0                 2228
# site.10.subj.MG03902304.lab.MG03902304.iso.1       rpoB 430.0                   69
# site.04.subj.03267.lab.824801.iso.1                rpoB 450.0                  362
# site.04.subj.05976.lab.916301.iso.1                rpoB 450.0                  219
# site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A58... rpoB 445.0                   48
#
# [248 rows x 20 columns]

# %% [markdown]
# We now plot the distribution of minor mutation counts for all 248 samples with one RIF RAV < 0.90 FRS

# %%
#plot the ditribution of minor alleles in the solo rif samples
fig, ax = plt.subplots(figsize=(2.5,2.5))
variant_count_all.MINOR_COUNT.plot(kind='hist', bins=range(0,3100,100), color='grey', ax=ax)
ax.set_xlabel('Number of heterogeneous mutations')
ax.set_ylabel('Number of samples')
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

# fig.savefig('pdf/bar-minor-allele-counts.pdf', bbox_inches='tight', transparent=True)

# %% [markdown]
# We can plot the assigned number of (sub)lineages from our pipeline on the distribution. For this, we need to get the corresponding rows from the `genomes` table.

# %%
variant_count_all.reset_index(inplace=True)
variant_count_all = variant_count_all.merge(genomes[['N_LINEAGES','SUBLINEAGE']], left_on='UNIQUEID', right_index=True, how='left')
variant_count_all
# Out:
#                                               UNIQUEID  GENE  GENE_POSITION
# 0         site.10.subj.NG00204540.lab.NG00204540.iso.1  rpoB          430.0  \
# 1           site.05.subj.LR-2502.lab.FN-01440-17.iso.1  rpoB          450.0
# 2                site.02.subj.0431.lab.235049-14.iso.1  rpoB          430.0
# 3               site.ENA.subj.SAMEA1403636.lab.1.iso.1  rpoB          450.0
# 4               site.ENA.subj.SAMN07978245.lab.1.iso.1  rpoB          450.0
# ..                                                 ...   ...            ...
# 243                site.04.subj.03297.lab.824687.iso.1  rpoB          430.0
# 244       site.10.subj.MG03902304.lab.MG03902304.iso.1  rpoB          430.0
# 245                site.04.subj.03267.lab.824801.iso.1  rpoB          450.0
# 246                site.04.subj.05976.lab.916301.iso.1  rpoB          450.0
# 247  site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A5...  rpoB          445.0
#
#     MINOR_MUTATION MUTATION  REF  ALT  NUCLEOTIDE_NUMBER  NUCLEOTIDE_INDEX
# 0            L430P    L430Z  ctg  ccg                NaN               NaN  \
# 1            S450L    S450Z  tcg  ttg                NaN               NaN
# 2            L430P    L430Z  ctg  ccg                NaN               NaN
# 3            S450L    S450Z  tcg  ttg                NaN               NaN
# 4            S450L    S450Z  tcg  ttg                NaN               NaN
# ..             ...      ...  ...  ...                ...               ...
# 243          L430P    L430Z  ctg  ccg                NaN               NaN
# 244          L430P    L430Z  ctg  ccg                NaN               NaN
# 245          S450L    S450Z  tcg  ttg                NaN               NaN
# 246          S450L    S450Z  tcg  ttg                NaN               NaN
# 247          H445D    H445Z  cac  gac                NaN               NaN
#
#      CODES_PROTEIN  ...  IS_NULL IS_MINOR  MINOR_READS GENE_MUTATION_POSITION
# 0             True  ...    False     True         18.0             rpoB_430.0  \
# 1             True  ...    False     True         30.0             rpoB_450.0
# 2             True  ...    False     True         10.0             rpoB_430.0
# 3             True  ...    False     True         40.0             rpoB_450.0
# 4             True  ...    False     True          4.0             rpoB_450.0
# ..             ...  ...      ...      ...          ...                    ...
# 243           True  ...    False     True          5.0             rpoB_430.0
# 244           True  ...    False     True         51.0             rpoB_430.0
# 245           True  ...    False     True         43.0             rpoB_450.0
# 246           True  ...    False     True          3.0             rpoB_450.0
# 247           True  ...    False     True         19.0             rpoB_445.0
#
#      COVERAGE       FRS  GENE_MUTATION  MINOR_COUNT N_LINEAGES
# 0        50.0  0.360000     rpoB_L430P          127          1  \
# 1        47.0  0.638298     rpoB_S450L          967          2
# 2       117.0  0.085470     rpoB_L430P          169          1
# 3        49.0  0.816327     rpoB_S450L          876          1
# 4         5.0  0.800000     rpoB_S450L          866          1
# ..        ...       ...            ...          ...        ...
# 243      18.0  0.277778     rpoB_L430P         2228          2
# 244      57.0  0.894737     rpoB_L430P           69          1
# 245      48.0  0.895833     rpoB_S450L          362          1
# 246      20.0  0.150000     rpoB_S450L          219          1
# 247      30.0  0.633333     rpoB_H445D           48          1
#
#                       SUBLINEAGE
# 0                   lineage2.2.4
# 1    lineage4.1.2.1/lineage4.3.3
# 2                   lineage4.2.2
# 3                  lineage2.2.10
# 4                     lineage2.1
# ..                           ...
# 243  lineage1.1.2/lineage4.1.2.1
# 244                 lineage2.2.7
# 245                 lineage2.2.7
# 246                 lineage3.1.2
# 247               lineage4.3.4.2
#
# [248 rows x 25 columns]

# %%
def extract_main_lineages(sublineage):
    if isinstance(sublineage, str):
        lineages = re.findall(r'lineage(\d+)', sublineage)  # Extract all main lineage numbers
        unique_lineages = sorted(set(lineages))  # Ensure uniqueness and sorted order
        return '+'.join(f'lineage{l}' for l in unique_lineages)  # Format as requested
    return sublineage  # Return unchanged if not a string

variant_count_all['LINEAGES'] = variant_count_all['SUBLINEAGE'].apply(extract_main_lineages)

variant_count_all
# Out:
#                                               UNIQUEID  GENE  GENE_POSITION
# 0         site.10.subj.NG00204540.lab.NG00204540.iso.1  rpoB          430.0  \
# 1           site.05.subj.LR-2502.lab.FN-01440-17.iso.1  rpoB          450.0
# 2                site.02.subj.0431.lab.235049-14.iso.1  rpoB          430.0
# 3               site.ENA.subj.SAMEA1403636.lab.1.iso.1  rpoB          450.0
# 4               site.ENA.subj.SAMN07978245.lab.1.iso.1  rpoB          450.0
# ..                                                 ...   ...            ...
# 243                site.04.subj.03297.lab.824687.iso.1  rpoB          430.0
# 244       site.10.subj.MG03902304.lab.MG03902304.iso.1  rpoB          430.0
# 245                site.04.subj.03267.lab.824801.iso.1  rpoB          450.0
# 246                site.04.subj.05976.lab.916301.iso.1  rpoB          450.0
# 247  site.07.subj.106F8637-1A3D-4BFC-BE5F-9040A87A5...  rpoB          445.0
#
#     MINOR_MUTATION MUTATION  REF  ALT  NUCLEOTIDE_NUMBER  NUCLEOTIDE_INDEX
# 0            L430P    L430Z  ctg  ccg                NaN               NaN  \
# 1            S450L    S450Z  tcg  ttg                NaN               NaN
# 2            L430P    L430Z  ctg  ccg                NaN               NaN
# 3            S450L    S450Z  tcg  ttg                NaN               NaN
# 4            S450L    S450Z  tcg  ttg                NaN               NaN
# ..             ...      ...  ...  ...                ...               ...
# 243          L430P    L430Z  ctg  ccg                NaN               NaN
# 244          L430P    L430Z  ctg  ccg                NaN               NaN
# 245          S450L    S450Z  tcg  ttg                NaN               NaN
# 246          S450L    S450Z  tcg  ttg                NaN               NaN
# 247          H445D    H445Z  cac  gac                NaN               NaN
#
#      CODES_PROTEIN  ...  IS_MINOR MINOR_READS  GENE_MUTATION_POSITION
# 0             True  ...      True        18.0              rpoB_430.0  \
# 1             True  ...      True        30.0              rpoB_450.0
# 2             True  ...      True        10.0              rpoB_430.0
# 3             True  ...      True        40.0              rpoB_450.0
# 4             True  ...      True         4.0              rpoB_450.0
# ..             ...  ...       ...         ...                     ...
# 243           True  ...      True         5.0              rpoB_430.0
# 244           True  ...      True        51.0              rpoB_430.0
# 245           True  ...      True        43.0              rpoB_450.0
# 246           True  ...      True         3.0              rpoB_450.0
# 247           True  ...      True        19.0              rpoB_445.0
#
#     COVERAGE       FRS  GENE_MUTATION  MINOR_COUNT  N_LINEAGES
# 0       50.0  0.360000     rpoB_L430P          127           1  \
# 1       47.0  0.638298     rpoB_S450L          967           2
# 2      117.0  0.085470     rpoB_L430P          169           1
# 3       49.0  0.816327     rpoB_S450L          876           1
# 4        5.0  0.800000     rpoB_S450L          866           1
# ..       ...       ...            ...          ...         ...
# 243     18.0  0.277778     rpoB_L430P         2228           2
# 244     57.0  0.894737     rpoB_L430P           69           1
# 245     48.0  0.895833     rpoB_S450L          362           1
# 246     20.0  0.150000     rpoB_S450L          219           1
# 247     30.0  0.633333     rpoB_H445D           48           1
#
#                       SUBLINEAGE           LINEAGES
# 0                   lineage2.2.4           lineage2
# 1    lineage4.1.2.1/lineage4.3.3           lineage4
# 2                   lineage4.2.2           lineage4
# 3                  lineage2.2.10           lineage2
# 4                     lineage2.1           lineage2
# ..                           ...                ...
# 243  lineage1.1.2/lineage4.1.2.1  lineage1+lineage4
# 244                 lineage2.2.7           lineage2
# 245                 lineage2.2.7           lineage2
# 246                 lineage3.1.2           lineage3
# 247               lineage4.3.4.2           lineage4
#
# [248 rows x 26 columns]

# %%
#make another column for the mixture type based on columns 'N_LINEAGES' and 'LINEAGES'
variant_count_all['MIXTURE_TYPE'] = np.where(
    (variant_count_all['N_LINEAGES'] > 1) & (~variant_count_all.LINEAGES.str.contains(r'\+', regex=True)), 'sublineages', 
    np.where((variant_count_all['N_LINEAGES'] > 1) & (variant_count_all.LINEAGES.str.contains(r'\+', regex=True)), 'lineages', 'single'))

variant_count_all.MIXTURE_TYPE.value_counts()
# Out:
# MIXTURE_TYPE
# single         163
# lineages        68
# sublineages     17
# Name: count, dtype: int64

# %% [markdown]
# We join the mykrobe results to our data table containing the number of minor alleles per sample

# %%
# Set up the figure and axes
fig, ax = plt.subplots(figsize=(2.5, 2.5))  # Adjust the size as needed

# Define colors for each group
colors = ['red', 'grey', 'pink']

# Group the data by the column with strings
groups = variant_count_all.groupby('MIXTURE_TYPE')

# Define the desired order for the legend
legend_order = ['single', 'sublineages', 'lineages']

# Store proxies for the legend
legend_proxies = {}

# Loop through each group and plot its histogram
for (label, group), color in zip(groups, colors):
    group['MINOR_COUNT'].plot(
        kind='hist',
        bins=range(0, 3100, 100),  # Adjust bin size if necessary
        color=color,
        alpha=0.5,  # Make bars semi-transparent for overlapping
        label=label,
        ax=ax
    )
    # Create a proxy artist for the legend
    if label in legend_order:
        legend_proxies[label] = mpatches.Patch(color=color, alpha=0.5)

# Add the legend with the correct order
ordered_proxies = [legend_proxies[label] for label in legend_order]
ax.legend(ordered_proxies, legend_order, title='Mixture', loc='upper right')

# Add labels and customize appearance
ax.set_ylim(0, 55)
ax.set_yticks(range(0, 60, 10))
ax.set_xlabel('Number of heterogeneous mutations')
ax.set_ylabel('Number of samples')
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

fig.savefig('pdf/bar-lineage-minor-allele-counts.pdf', bbox_inches='tight', transparent=True)

# %% [markdown]
# Make a plot showing the difference in minor allele count in samples with and without Lineage 1 in the lineage mixture

# %%
unique_lineages = variant_count_all.LINEAGES.unique()

# keep only the sample with two lineages
unique_lineages = [lineage for lineage in unique_lineages if '+' in lineage]

unique_lineages = unique_lineages[:6]
unique_lineages.sort()
unique_lineages
# Out:
# ['lineage1+lineage2',
#  'lineage1+lineage3',
#  'lineage1+lineage4',
#  'lineage2+lineage3',
#  'lineage2+lineage4',
#  'lineage3+lineage4']

# %%
#combine the bins for modern and ancient lineages, respectively
unique_lineages_1 = unique_lineages[:3]
unique_lineages_2 = unique_lineages[-3:]

#make list of lists, where each list is a list of the unique lineages
unique_lineages_combined = [unique_lineages_1, unique_lineages_2]

fig = plt.figure(figsize=(2.5, 2.5))
axes = fig.gca()

for i, lineages in enumerate(unique_lineages_combined):
    tmp = variant_count_all[(variant_count_all.MIXTURE_TYPE == 'lineages') & (variant_count_all.LINEAGES.isin(lineages))]
    axes.boxplot(tmp.MINOR_COUNT, positions=[i], showfliers=False, patch_artist=True, boxprops=dict(facecolor='red'), widths=0.3)

axes.set_xticks(range(len(unique_lineages_combined)))
# axes.set_xticklabels(['+'.join(lineages) for lineages in unique_lineages_combined], rotation=45)
axes.set_xticklabels(['True','False'])
axes.set_xlim(-1, len(unique_lineages_combined))
axes.set_ylim(0, 3500)
axes.set_xlabel('Contains Lineage 1')
axes.set_ylabel('Heterogeneous mutations count')
axes.spines[["right", "top"]].set_visible(False)

fig.savefig('pdf/minor_allele_lineage_mix_combined.pdf', bbox_inches='tight', transparent=True)

# %%
sum_lin = variant_count_all[(variant_count_all.MIXTURE_TYPE == 'lineages') & (variant_count_all.LINEAGES.isin(unique_lineages[0:2]))].MINOR_COUNT.sum()
count_lin = len(variant_count_all[(variant_count_all.MIXTURE_TYPE == 'lineages') & (variant_count_all.LINEAGES==unique_lineages[0])])
print("The average minor allele count for samples containing Lineage 1 is", round(sum_lin/count_lin,0))
# Out:
# The average minor allele count for samples containing Lineage 1 is 2598.0

# %%
sum_lin = variant_count_all[(variant_count_all.MIXTURE_TYPE == 'lineages') & (variant_count_all.LINEAGES.isin(unique_lineages[2:4]))].MINOR_COUNT.sum()
count_lin = len(variant_count_all[(variant_count_all.MIXTURE_TYPE == 'lineages') & (variant_count_all.LINEAGES==unique_lineages[0])])
print("The average minor allele count for samples containing only modern M. tb lineages is", round(sum_lin/count_lin,0))
# Out:
# The average minor allele count for samples containing only modern M. tb lineages is 2240.0

# %%
# add CM flag to variant_count_all where mutations has a CM
mutations['HAS_COMPENSATORY_MUTATION'] = mutations['GENE_MUTATION'].isin(compensatory_mutations)
variant_count_all['CM'] = variant_count_all['UNIQUEID'].isin(mutations[mutations.HAS_COMPENSATORY_MUTATION].UNIQUEID)
variant_count_all[variant_count_all['CM']]
# Out:
#                                               UNIQUEID  GENE  GENE_POSITION
# 6                  site.04.subj.00574.lab.706414.iso.1  rpoB          450.0  \
# 8             site.08.subj.28TB-D06-009.lab.2849.iso.1  rpoB          450.0
# 9                  site.04.subj.05164.lab.928554.iso.1  rpoB          450.0
# 10   site.03.subj.2731-02_LIB9184.lab.2731-02_LIB91...  rpoB          432.0
# 12          site.05.subj.LS-1669.lab.MA-01736-19.iso.1  rpoB          450.0
# ..                                                 ...   ...            ...
# 234        site.05.subj.LI2174109.lab.14893_2_18.iso.1  rpoB          450.0
# 235                site.04.subj.06221.lab.943340.iso.1  rpoB          450.0
# 237     site.08.subj.BTN_P299_17.lab.BTN_P299_17.iso.1  rpoB          450.0
# 238         site.05.subj.LR-2285.lab.FN-00492-18.iso.1  rpoB          450.0
# 245                site.04.subj.03267.lab.824801.iso.1  rpoB          450.0
#
#     MINOR_MUTATION MUTATION  REF  ALT  NUCLEOTIDE_NUMBER  NUCLEOTIDE_INDEX
# 6            S450L    S450Z  tcg  ttg                NaN               NaN  \
# 8            S450L    S450Z  tcg  ttg                NaN               NaN
# 9            S450L    S450Z  tcg  ttg                NaN               NaN
# 10           Q432P    Q432Z  caa  cca                NaN               NaN
# 12           S450L    S450Z  tcg  ttg                NaN               NaN
# ..             ...      ...  ...  ...                ...               ...
# 234          S450L    S450Z  tcg  ttg                NaN               NaN
# 235          S450L    S450Z  tcg  ttg                NaN               NaN
# 237          S450L    S450Z  tcg  ttg                NaN               NaN
# 238          S450L    S450Z  tcg  ttg                NaN               NaN
# 245          S450L    S450Z  tcg  ttg                NaN               NaN
#
#      CODES_PROTEIN  ...  GENE_MUTATION_POSITION COVERAGE       FRS
# 6             True  ...              rpoB_450.0     53.0  0.509434  \
# 8             True  ...              rpoB_450.0     11.0  0.454545
# 9             True  ...              rpoB_450.0     28.0  0.142857
# 10            True  ...              rpoB_432.0     80.0  0.575000
# 12            True  ...              rpoB_450.0     14.0  0.428571
# ..             ...  ...                     ...      ...       ...
# 234           True  ...              rpoB_450.0     36.0  0.750000
# 235           True  ...              rpoB_450.0     17.0  0.705882
# 237           True  ...              rpoB_450.0     91.0  0.318681
# 238           True  ...              rpoB_450.0     53.0  0.849057
# 245           True  ...              rpoB_450.0     48.0  0.895833
#
#     GENE_MUTATION  MINOR_COUNT  N_LINEAGES                    SUBLINEAGE
# 6      rpoB_S450L         2681           2   lineage1.2.2/lineage4.4.1.1  \
# 8      rpoB_S450L         2111           2     lineage1.1.1/lineage2.2.7
# 9      rpoB_S450L          349           1                lineage4.1.2.1
# 10     rpoB_Q432P         1497           2  lineage2.2.10/lineage4.1.2.1
# 12     rpoB_S450L          489           1                  lineage4.3.2
# ..            ...          ...         ...                           ...
# 234    rpoB_S450L          289           1                  lineage4.3.3
# 235    rpoB_S450L         1187           1                  lineage2.2.7
# 237    rpoB_S450L          429           1                    lineage2.2
# 238    rpoB_S450L          732           1                      lineage4
# 245    rpoB_S450L          362           1                  lineage2.2.7
#
#               LINEAGES MIXTURE_TYPE    CM
# 6    lineage1+lineage4     lineages  True
# 8    lineage1+lineage2     lineages  True
# 9             lineage4       single  True
# 10   lineage2+lineage4     lineages  True
# 12            lineage4       single  True
# ..                 ...          ...   ...
# 234           lineage4       single  True
# 235           lineage2       single  True
# 237           lineage2       single  True
# 238           lineage4       single  True
# 245           lineage2       single  True
#
# [98 rows x 28 columns]

# %%
contingency = pd.crosstab(variant_count_all.CM, variant_count_all.MIXTURE_TYPE)
# contingency['single_sublineages'] = contingency['single'] + contingency['sublineages']
contingency['multiple_(sub)lineages'] = contingency['lineages'] + contingency['sublineages']

# contingency.drop(columns=['single', 'sublineages'], inplace=True)
contingency.drop(columns=['lineages', 'sublineages'], inplace=True)

print(contingency)
# Out:
# MIXTURE_TYPE  single  multiple_(sub)lineages
# CM
# False            112                      38
# True              51                      47

# %%
# test for signifcance
odds_ratio, p_value = fisher_exact(contingency)
print("The fishers exact p-value for the association of CMs with the mixture type is {:.2e}".format(p_value))
# Out:
# The fishers exact p-value for the association of CMs with the mixture type is 3.49e-04

# %% [markdown]
# nvestigate the FRS of the RAV compared to the rest of the heterogeneous mutations in the samples with multiple (sub)lineages

# %%
def plot_frs_histogram(df, RAV_FRS=None, lineage_count=None, savefig=False, i=None):
    """
    Plot the FRS distribution for a given DataFrame with optional RAV FRS line.
    
    Parameters:
    df (pd.DataFrame): DataFrame containing 'FRS' column.
    RAV_FRS (float): RAV FRS value to mark with vertical line.
    lineage_count (int): Number of lineages for the RAV variant.
    savefig (bool): Whether to save the figure as a PDF.
    """
    # Create figure with better styling
    fig, ax = plt.subplots(figsize=(5, 4))
    
    # Create histogram with improved styling
    n, bins, patches = ax.hist(df['FRS'], bins=50, color='red', alpha=0.7, 
                               linewidth=0.5)
    
    # # Add vertical line(s) for RAV FRS if provided
    # if RAV_FRS is not None:
    #     label_text = 'RAV FRS'
    #     ax.axvline(x=RAV_FRS, color='black', linestyle='--', linewidth=2.5, 
    #                alpha=0.9, label=label_text)
        
    #     # Add legend with better styling
    #     legend = ax.legend(loc='upper right', framealpha=0.9)
    #     # legend.get_frame().set_facecolor('#f8f9fa')
    
    # Improve axis labels and title
    ax.set_xlabel('Fraction of Reads Supporting Mutation (FRS)', fontsize=12)
    ax.set_ylabel('Number of Mutations', fontsize=12)
    # ax.set_title(lineage_count, fontsize=14, pad=20)
    
    # Remove top and right spines for cleaner look
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_linewidth(0.8)
    ax.spines['bottom'].set_linewidth(0.8)
    
    # Improve tick styling
    ax.tick_params(axis='both', which='major', labelsize=10, length=4, width=0.8)
    ax.tick_params(axis='both', which='minor', length=2, width=0.5)
    
    # Set x-axis limits and add grid
    ax.set_xlim(0, 1)
    # ax.grid(True, alpha=0.3, linestyle='-', linewidth=0.5)
    ax.set_axisbelow(True)
    
    # Improve layout
    plt.tight_layout()
    
    if savefig:
        # plt.savefig(f'pdf/fig-random-sample-frs-distribution_{i}-no_RAV.pdf', bbox_inches='tight', 
        #            transparent=True, dpi=300)
        plt.savefig(f'pdf/fig-random-sample-frs-distribution_{i}_RAV.svg', format='svg', dpi=1200, bbox_inches='tight')
    
    plt.show()

# %%
variant_count_lin = variant_count_all[(variant_count_all.MIXTURE_TYPE=='lineages') | (variant_count_all.MIXTURE_TYPE=='sublineages')]
print(f"Testing phasing for all {len(variant_count_lin.UNIQUEID)} heterogeneous samples with multiple (sub)lineages")

for i, sample_id in enumerate(variant_count_lin.UNIQUEID):
    sample_data = solo_other_variants[solo_other_variants.UNIQUEID == sample_id]
    RAV_FRS = variant_count_lin[variant_count_lin.UNIQUEID == sample_id].FRS.iloc[0]
    lineage_count = variant_count_lin[variant_count_lin.UNIQUEID == sample_id].N_LINEAGES.iloc[0]
    plot_frs_histogram(sample_data, RAV_FRS=RAV_FRS, lineage_count= lineage_count, savefig=True, i=i+1)
# Out:
# Testing phasing for all 85 heterogeneous samples with multiple (sub)lineages
